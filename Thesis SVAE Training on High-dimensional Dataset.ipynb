# %% [markdown]
# # SVAE Training on High-dimensional Register Data

# %% [markdown]
# In this report, we will be training our SVAE models on high-dimensional dataset which is one of the two versions of register dataset used in this thesis. These are:
#
# - 1- High-dimensional Dataset: The dataset where we only removed features that are fully correlated and having zero variance
# - 2- Moderate-dimensional Dataset: The dataset where we removed features with correlation threshold of 0.9 and variance threshold of 1%.
#
# Each Dataset is trained with 5-Fold Cross-Validation method. The hyperparameters of SVAEs are trained in two steps.

# %% [markdown]
# The hyperparameters of the **first step** are:
# - Number of Hidden Layers in Encoder/Decoder
# - Number of Neurons in Hidden Layers of Encoder/Decoder
# - Number of Hidden Layers in Classifier
# - Number of Neurons in Hidden Layers of Classifier
# - Latent Size
#
# The hyperparameters of the **second step** are:
# - alpha
# - beta
# - weight decay

# %% [markdown]
# After finding best hyperparameters in the end of hyperparameter tuning, we will test the performance on validation test data which was not included in the validation training data.

# %% [markdown]
# ### Importing required packages

# %%
import sys
import torch
import argparse
from torch.utils.data import DataLoader
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from custom_reg_dataset import RegisterDataset
from datetime import datetime
from timeit import default_timer as timer
import time
from statistics import mean as mean_calc

import os

import pytorch_warmup as warmup

from models.SVAE import SVAE
#from custom_dataset import TerraDataset
from utils.loss_fn import loss_fn_SVAE

from pytorchtools import EarlyStopping

from training_methods import cv_fold_maker, hyperparameter_tuner, model_test,latent_corr_calc

from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import random
import numpy as np

# %% [markdown]
# ## 1.Training on High-Dimensional Dataset

# %% [markdown]
# In this part of the report, we will concentrate on the training of the high-dimensional dataset. Before starting training, we will set the device as GPU and prepare convert training data into dataloaders which will be used in training process of SVAEs.

# %%
seed = 1
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# Importing the validation training data and validation test data prepared for High-dimensional dataset training.

# %%
highdim_valtrain_5f = pd.read_csv("fused_data_valtrain_5f_d365.txt", sep = "\t")
highdim_valtest = pd.read_csv("fused_data_valtest_d365.txt", sep = "\t")

# %% [markdown]
# Preparing dataloaders for training folds and validation folds to be used in hyperparameter tuning.

# %%
num_folds = 5
batch_size = 64

Dataloader_list, dataset_val_list, highdims = cv_fold_maker(highdim_valtrain_5f, num_folds, batch_size, seed = seed)

# %% [markdown]
# Prepared data are moved to device(GPU) and added to lists which will be iterated throughout the 5-Fold Cross Validation.
#
# The order of folds in 5-Fold Cross Validation will be as in the following:
# - Training Folds: 2, 3, 4, 5 / Validation Fold: 1
# - Training Folds: 1, 3, 4, 5 / Validation Fold: 2
# - Training Folds: 1, 2, 4, 5 / Validation Fold: 3
# - Training Folds: 1, 2, 3, 5 / Validation Fold: 4
# - Training Folds: 1, 2, 3, 4 / Validation Fold: 5

# %%
X_val_list = []
y_val_list = []

for dataset in dataset_val_list:
    X_val = dataset.x
    X_val = X_val.to(device)
    
    y_val = dataset.y
    y_val = y_val.to(device)
    
    X_val_list.append(X_val)
    y_val_list.append(y_val)

# %% [markdown]
# In above code, we create lists for validation fold data and validaton fold labels.

# %% [markdown]
# ### 1.1 Hyperparameter Tuning Step 1: NN Architecture

# %% [markdown]
# In this first step of hyperparameter tuning, we will tune the hyperparameters related to Neural Network Architectures.

# %% [markdown]
# The parameters which will be stable throughout this hyperparameter tuning step are:

# %%
batch_size_list = [64]
w_decay_list = [10**-4]
alpha_list = [1]
beta_list = [1]
lr_list= [0.001]
es_thr = 100

# %% [markdown]
# The parameters which will be tuned in this hyperparameter tuning step are:

# %%
#encoder number of layers = 1, 3, 5 / encoder number of neurons each layer = 128, 256, 512
encoder_layer_list = [[highdims, 128], [highdims, 256], [highdims, 512], [highdims, 128, 128, 128], \
                      [highdims, 256, 256, 256], [highdims, 512, 512, 512], [highdims, 128, 128, 128, 128, 128] ,\
                     [highdims, 256, 256, 256, 256, 256], [highdims, 512, 512, 512, 512, 512]]
#classifier number of layers = 1, 3, 5 / classifier number of neurons each layer = 128, 256, 512
classifier_layer_list = [[128, 1], [256, 1], [512, 1], [128,128,128, 1], [256,256,256, 1], [512, 512, 512, 1],\
                        [128, 128, 128, 128, 128, 1], [256, 256, 256, 256, 256, 1], [512, 512, 512, 512, 512, 1]]
#number of dimensions in the latent space
latent_size_list = [2, 8, 32, 64, 128]

# %% [markdown]
# Now we will use *hyperparameter_tuning* function in order to train SVAE models.

# %%
highdim_report_step1, highdim_loss_step1_list, highdim_loss_step1_names = hyperparameter_tuner(device, highdims, num_folds, 
                                                                                               Dataloader_list,
                         X_val_list, y_val_list, batch_size_list, w_decay_list, alpha_list, beta_list, lr_list,
                         encoder_layer_list, classifier_layer_list, latent_size_list, seed = seed, es_thr = es_thr)
# Out:
# Training start date is: 2023-05-08 17:26:11.982795
# ./net_weights/SVAE_models_08-05-2023_17-26-11 directory is created
# 08-05-2023_17-26-11_loss_logs directory is created under H:\Projects\My Thesis\loss_values\
# 1 settings have been checked and saved to report file
# 6 settings have been checked and saved to report file
# 11 settings have been checked and saved to report file
# 16 settings have been checked and saved to report file
# 21 settings have been checked and saved to report file
# 26 settings have been checked and saved to report file
# 31 settings have been checked and saved to report file
# 36 settings have been checked and saved to report file
# 41 settings have been checked and saved to report file
# 46 settings have been checked and saved to report file
# 51 settings have been checked and saved to report file
# 56 settings have been checked and saved to report file
# 61 settings have been checked and saved to report file
# 66 settings have been checked and saved to report file
# 71 settings have been checked and saved to report file
# 76 settings have been checked and saved to report file
# 81 settings have been checked and saved to report file
# 86 settings have been checked and saved to report file
# 91 settings have been checked and saved to report file
# 96 settings have been checked and saved to report file
# 101 settings have been checked and saved to report file
# 106 settings have been checked and saved to report file
# 111 settings have been checked and saved to report file
# 116 settings have been checked and saved to report file
# 121 settings have been checked and saved to report file
# 126 settings have been checked and saved to report file
# 131 settings have been checked and saved to report file
# 136 settings have been checked and saved to report file
# 141 settings have been checked and saved to report file
# 146 settings have been checked and saved to report file
# 151 settings have been checked and saved to report file
# 156 settings have been checked and saved to report file
# 161 settings have been checked and saved to report file
# 166 settings have been checked and saved to report file
# 171 settings have been checked and saved to report file
# 176 settings have been checked and saved to report file
# 181 settings have been checked and saved to report file
# 186 settings have been checked and saved to report file
# 191 settings have been checked and saved to report file
# 196 settings have been checked and saved to report file
# 201 settings have been checked and saved to report file
# 206 settings have been checked and saved to report file
# 211 settings have been checked and saved to report file
# 216 settings have been checked and saved to report file
# 221 settings have been checked and saved to report file
# 226 settings have been checked and saved to report file
# 231 settings have been checked and saved to report file
# 236 settings have been checked and saved to report file
# 241 settings have been checked and saved to report file
# 246 settings have been checked and saved to report file
# 251 settings have been checked and saved to report file
# 256 settings have been checked and saved to report file
# 261 settings have been checked and saved to report file
# 266 settings have been checked and saved to report file
# 271 settings have been checked and saved to report file
# 276 settings have been checked and saved to report file
# 281 settings have been checked and saved to report file
# 286 settings have been checked and saved to report file
# 291 settings have been checked and saved to report file
# 296 settings have been checked and saved to report file
# 301 settings have been checked and saved to report file
# 306 settings have been checked and saved to report file
# 311 settings have been checked and saved to report file
# 316 settings have been checked and saved to report file
# 321 settings have been checked and saved to report file
# 326 settings have been checked and saved to report file
# 331 settings have been checked and saved to report file
# 336 settings have been checked and saved to report file
# 341 settings have been checked and saved to report file
# 346 settings have been checked and saved to report file
# 351 settings have been checked and saved to report file
# 356 settings have been checked and saved to report file
# 361 settings have been checked and saved to report file
# 366 settings have been checked and saved to report file
# 371 settings have been checked and saved to report file
# 376 settings have been checked and saved to report file
# 381 settings have been checked and saved to report file
# 386 settings have been checked and saved to report file
# 391 settings have been checked and saved to report file
# 396 settings have been checked and saved to report file
# 401 settings have been checked and saved to report file
# Training end date is: 2023-05-14 23:02:19.683670
# Total Training Time is: 05:36:00

# %% [markdown]
# #### Hyperparameter Tuning Step 1 Results

# %% [markdown]
# #### Mean Auroc

# %%
highdim_report_step1.sort_values(by=["CV_avg_val_auroc"], ascending = False)
# Out:
#      Model_number  Seed  Batch_size  Encoder_num_neurons  \
# 399           400     1          64                  512
# 359           360     1          64                  256
# 224           225     1          64                  256
# 365           366     1          64                  512
# 376           377     1          64                  512
# ..            ...   ...         ...                  ...
# 93             94     1          64                  512
# 121           122     1          64                  512
# 2               3     1          64                  128
# 22             23     1          64                  128
# 107           108     1          64                  512
#
#      Encoder_num_hidden_layers  Clf_num_neurons  Clf_num_hidden_layers  \
# 399                          5              256                      5
# 359                          5              512                      5
# 224                          3              512                      5
# 365                          5              256                      1
# 376                          5              128                      3
# ..                         ...              ...                    ...
# 93                           1              128                      1
# 121                          1              128                      5
# 2                            1              128                      1
# 22                           1              256                      3
# 107                          1              128                      3
#
#      Latent_size  Alpha  Beta  ...  CV3_val_acc  CV4_val_acc  CV5_val_acc  \
# 399          128      1     1  ...     0.587395     0.565401     0.552013
# 359          128      1     1  ...     0.556303     0.569620     0.521812
# 224          128      1     1  ...     0.452941     0.576371     0.529362
# 365            2      1     1  ...     0.609244     0.627848     0.618289
# 376            8      1     1  ...     0.552941     0.590717     0.553691
# ..           ...    ...   ...  ...          ...          ...          ...
# 93            64      1     1  ...     0.526050     0.520675     0.557886
# 121            8      1     1  ...     0.525210     0.552743     0.531040
# 2             32      1     1  ...     0.527731     0.556118     0.536074
# 22            32      1     1  ...     0.512605     0.532489     0.514262
# 107           32      1     1  ...     0.542017     0.501266     0.497483
#
#      CV1_val_auroc  CV2_val_auroc  CV3_val_auroc  CV4_val_auroc  \
# 399       0.569659       0.594262       0.593246       0.585840
# 359       0.578966       0.613036       0.571067       0.580295
# 224       0.571938       0.579105       0.592878       0.575815
# 365       0.569762       0.587092       0.594570       0.573180
# 376       0.564092       0.598918       0.578684       0.591941
# ..             ...            ...            ...            ...
# 93        0.556105       0.541329       0.538957       0.524394
# 121       0.526394       0.550791       0.535786       0.565294
# 2         0.548734       0.550958       0.521035       0.545695
# 22        0.538343       0.566210       0.510650       0.535378
# 107       0.537597       0.549264       0.546595       0.540550
#
#      CV5_val_auroc  CV_avg_val_acc  CV_avg_val_auroc
# 399       0.573016        0.563818          0.583205
# 359       0.564298        0.540919          0.581532
# 224       0.585180        0.544034          0.580983
# 365       0.578116        0.612669          0.580544
# 376       0.566490        0.578024          0.580025
# ..             ...             ...               ...
# 93        0.551548        0.534172          0.542467
# 121       0.525031        0.530654          0.540659
# 2         0.534826        0.545326          0.540250
# 22        0.542144        0.527139          0.538545
# 107       0.518151        0.515320          0.538432
#
# [405 rows x 54 columns]

# %% [markdown]
# Based on the results the best settings we got from the step 1 hyperparameter tuning are:
#
# - Number of Hidden Layers in Encoder/Decoder = 5
# - Number of Neurons in Hidden Layers of Encoder/Decoder = 512
# - Number of Hidden Layers in Classifier = 5
# - Number of Neurons in Hidden Layers of Classifier = 256
# - Latent Size = 128

# %% [markdown]
# ### 1.2 Hyperparameter Tuning Step 2: Loss Hyperparameters

# %% [markdown]
# In this second step of hyperparameter tuning, we will tune the loss hyperparameters such as weight decay used for regularization and loss calculation hyperparameters alpha and beta.

# %% [markdown]
# The parameters which will be stable throughout this hyperparameter tuning step are:

# %%
batch_size_list = [64]
lr_list= [0.001]
es_thr = 100 

#Best values for number of nodes and hidden layers found for encoder/decoder in first tuning step was:
encoder_layer_list = [[highdims, 512, 512, 512, 512, 512]]
#Best values for number of nodes and hidden layers found for classifier in first tuning step was:
classifier_layer_list = [[256, 256, 256, 256, 256, 1]]

latent_size_list = [128]

# %% [markdown]
# The parameters which will be tuned in this hyperparameter tuning step are:

# %%
w_decay_list = [1, 10**-2, 10**-4, 10**-6]
alpha_list = [0.1, 1, 10, 100]
beta_list = [0.1, 1, 10, 100]

# %% [markdown]
# Now we will use *hyperparameter_tuning* function in order to train SVAE models based on the results we got from first step.

# %%
highdim_report_step2,highdim_loss_step2_list, highdim_loss_step2_names = hyperparameter_tuner(device, highdims, num_folds, Dataloader_list,
                         X_val_list, y_val_list, batch_size_list, w_decay_list, alpha_list, beta_list, lr_list,
                         encoder_layer_list, classifier_layer_list, latent_size_list, seed = seed, es_thr = es_thr)
# Out:
# Training start date is: 2023-05-15 01:44:25.657980
# ./net_weights/SVAE_models_15-05-2023_01-44-25 directory is created
# 15-05-2023_01-44-25_loss_logs directory is created under H:\Projects\My Thesis\loss_values\
# 1 settings have been checked and saved to report file
# 6 settings have been checked and saved to report file
# 11 settings have been checked and saved to report file
# 16 settings have been checked and saved to report file
# 21 settings have been checked and saved to report file
# 26 settings have been checked and saved to report file
# 31 settings have been checked and saved to report file
# 36 settings have been checked and saved to report file
# 41 settings have been checked and saved to report file
# 46 settings have been checked and saved to report file
# 51 settings have been checked and saved to report file
# 56 settings have been checked and saved to report file
# 61 settings have been checked and saved to report file
# Training end date is: 2023-05-16 09:24:39.487368
# Total Training Time is: 07:40:12

# %% [markdown]
# #### Hyperparameter Tuning Step 2 Results

# %% [markdown]
# #### Mean Auroc

# %%
highdim_report_step2.sort_values(by=["CV_avg_val_auroc"], ascending = False)
# Out:
#     Model_number  Seed  Batch_size  Encoder_num_neurons  \
# 37            38     1          64                  512
# 49            50     1          64                  512
# 38            39     1          64                  512
# 54            55     1          64                  512
# 50            51     1          64                  512
# ..           ...   ...         ...                  ...
# 61            62     1          64                  512
# 6              7     1          64                  512
# 7              8     1          64                  512
# 26            27     1          64                  512
# 1              2     1          64                  512
#
#     Encoder_num_hidden_layers  Clf_num_neurons  Clf_num_hidden_layers  \
# 37                          5              256                      5
# 49                          5              256                      5
# 38                          5              256                      5
# 54                          5              256                      5
# 50                          5              256                      5
# ..                        ...              ...                    ...
# 61                          5              256                      5
# 6                           5              256                      5
# 7                           5              256                      5
# 26                          5              256                      5
# 1                           5              256                      5
#
#     Latent_size  Alpha   Beta  ...  CV3_val_acc  CV4_val_acc  CV5_val_acc  \
# 37          128    1.0    1.0  ...     0.519328     0.577215     0.613255
# 49          128    0.1    1.0  ...     0.452941     0.576371     0.529362
# 38          128    1.0   10.0  ...     0.607563     0.592405     0.569631
# 54          128    1.0   10.0  ...     0.535294     0.521519     0.456376
# 50          128    0.1   10.0  ...     0.505042     0.514768     0.619966
# ..          ...    ...    ...  ...          ...          ...          ...
# 61          128  100.0    1.0  ...     0.585714     0.602532     0.602349
# 6           128    1.0   10.0  ...     0.609244     0.629536     0.619966
# 7           128    1.0  100.0  ...     0.609244     0.629536     0.619966
# 26          128   10.0   10.0  ...     0.556303     0.573840     0.573826
# 1           128    0.1    1.0  ...     0.609244     0.629536     0.619966
#
#     CV1_val_auroc  CV2_val_auroc  CV3_val_auroc  CV4_val_auroc  CV5_val_auroc  \
# 37       0.564609       0.608070       0.580850       0.598203       0.561071
# 49       0.571938       0.579105       0.592878       0.575815       0.585180
# 38       0.562406       0.581693       0.595868       0.576676       0.574040
# 54       0.565510       0.570755       0.600122       0.580811       0.572416
# 50       0.566116       0.580103       0.582730       0.582789       0.574743
# ..            ...            ...            ...            ...            ...
# 61       0.536806       0.565063       0.570133       0.558719       0.547085
# 6        0.542119       0.547639       0.563258       0.559500       0.560264
# 7        0.564031       0.553112       0.538766       0.560090       0.554114
# 26       0.535424       0.550374       0.567288       0.563113       0.553173
# 1        0.517686       0.560424       0.578621       0.536927       0.558296
#
#     CV_avg_val_acc  CV_avg_val_auroc
# 37        0.551665          0.582561
# 49        0.544034          0.580983
# 38        0.580487          0.578136
# 54        0.535979          0.577923
# 50        0.521918          0.577296
# ..             ...               ...
# 61        0.588897          0.555561
# 6         0.614694          0.554556
# 7         0.614694          0.554023
# 26        0.557915          0.553874
# 1         0.614694          0.550391
#
# [64 rows x 54 columns]

# %% [markdown]
# Based on the results the best settings we got from the step 2 hyperparameter tuning are:
#
# - alpha = 1
# - beta = 1
# - weight decay = 0.0001

# %% [markdown]
# ### 1.3 High-dimensional Dataset Hyperparameter Tuning Result

# %% [markdown]
# In the end, the best SVAE hyperparameter values for the high-dimensional dataset are:
#
# - Number of Hidden Layers in Encoder/Decoder = 5
# - Number of Neurons in Hidden Layers of Encoder/Decoder = 512
# - Number of Hidden Layers in Classifier = 5
# - Number of Neurons in Hidden Layers of Classifier = 256
# - Latent Size = 128
# - alpha = 1
# - beta = 1
# - weight decay = 0.0001

# %% [markdown]
# ## 2. Testing on Validation Test Data

# %% [markdown]
# As we have found the best SVAE hyperparameter values for high-dimensional dataset, we can check their performance on validation test data which was not included in hyperparameter tuning.

# %% [markdown]
# ### 2.1 Testing on Validation Test Data for High-dimensional Data

# %% [markdown]
# - Number of Hidden Layers in Encoder/Decoder = 5
# - Number of Neurons in Hidden Layers of Encoder/Decoder = 512
# - Number of Hidden Layers in Classifier = 5
# - Number of Neurons in Hidden Layers of Classifier = 256
# - Latent Size = 128
# - alpha = 1
# - beta = 1
# - weight decay = 0.0001

# %%
train_df = highdim_valtrain_5f
test_df = highdim_valtest
column_names = test_df.drop(columns = ["persistence_d365","pid"]).columns

# %%
batch_size = 64
lr_init = 0.001
es_thr = 100
es_active = True

# %%
#Hyperparameters tuned in step 1
encoder_layers = [highdims, 512, 512, 512, 512, 512]
classifier_layers = [256, 256, 256, 256, 256, 1]
latent_size = 128
#Hyperparameters tuned in step 2
w_decay = 0.0001
alpha = 1
beta = 1

# %%
report_df_highdim_data = pd.DataFrame(columns = ["seed", "best_auroc_epoch","best_loss_epoch", "accuracy", "auroc"])

# %%
seeds_list = list(range(1,500,10))

# %%
now = datetime.now()

# dd/mm/YY H:M:S
dt_string = now.strftime("%d-%m-%Y_%H-%M-%S")
seeds_corr_list = []

for i, seed in enumerate(seeds_list):
    print("seed is", seed)
    best_auroc_epoch, best_loss_epoch, acc_score, auroc_score, X_test, y_test, eval_z, eval_pred_labels, eval_pred_prob = model_test(device, 
           train_df, test_df, batch_size, w_decay, alpha, 
           beta, lr_init, encoder_layers, classifier_layers,latent_size, 
            epochs = 500, seed = seed, es_active = es_active, es_thr = es_thr, es_patience = 10, 
           datestring = dt_string, shuffling = False)
    
    #Creating new result row
    results = [seed, best_auroc_epoch, best_loss_epoch, acc_score, auroc_score]
    #adding created result row to the report
    report_df_highdim_data.loc[len(report_df_highdim_data)] = results
    #top variables correlated with latent features are calculated
    latent_f_top_vars_list = latent_corr_calc(X_test, column_names, eval_z)
    #adding the top variables calculated with the specified random seed
    seeds_corr_list.append(latent_f_top_vars_list)
    
 
    
current_dir = os.getcwd()
report_folder = current_dir + "\hyperparameter_reports\\"
if not os.path.exists(report_folder):
    os.mkdir(report_folder)
    print("hyperparameter_reports directory is created under " + current_dir)
    
report_df_highdim_data.to_csv(os.path.join(report_folder,"highdim_data_valtest_report_"+ dt_string +  ".txt"), sep = "\t", index = False)
# Out:
# seed is 1
# ./net_weights/SVAE_models_16-05-2023_10-06-19/ directory is created
# 16-05-2023_10-06-19_loss_logs directory is created under H:\Projects\My Thesis\loss_values\
# Accuracy Score on the test data is: 0.6075187969924812
# ROC-AUC Score on the test data is: 0.6148487643645029
# seed is 11
# Accuracy Score on the test data is: 0.6270676691729323
# ROC-AUC Score on the test data is: 0.6027614435604751
# seed is 21
# Accuracy Score on the test data is: 0.6075187969924812
# ROC-AUC Score on the test data is: 0.5965063991698374
# seed is 31
# Accuracy Score on the test data is: 0.6225563909774436
# ROC-AUC Score on the test data is: 0.6018774741535032
# seed is 41
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.5752142664975595
# seed is 51
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.5894154271878242
# seed is 61
# Accuracy Score on the test data is: 0.6285714285714286
# ROC-AUC Score on the test data is: 0.5847649794381029
# seed is 71
# Accuracy Score on the test data is: 0.5924812030075188
# ROC-AUC Score on the test data is: 0.5948729774395634
# seed is 81
# Accuracy Score on the test data is: 0.6045112781954888
# ROC-AUC Score on the test data is: 0.5541527345401438
# seed is 91
# Accuracy Score on the test data is: 0.6285714285714286
# ROC-AUC Score on the test data is: 0.5908278565663554
# seed is 101
# Accuracy Score on the test data is: 0.6225563909774436
# ROC-AUC Score on the test data is: 0.5963238402705715
# seed is 111
# Accuracy Score on the test data is: 0.6285714285714286
# ROC-AUC Score on the test data is: 0.5962277566393789
# seed is 121
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.5960067642876361
# seed is 131
# Accuracy Score on the test data is: 0.6225563909774436
# ROC-AUC Score on the test data is: 0.6083919443483607
# seed is 141
# Accuracy Score on the test data is: 0.6406015037593985
# ROC-AUC Score on the test data is: 0.6127349244782658
# seed is 151
# Accuracy Score on the test data is: 0.6180451127819548
# ROC-AUC Score on the test data is: 0.5881759483454398
# seed is 161
# Accuracy Score on the test data is: 0.6240601503759399
# ROC-AUC Score on the test data is: 0.6102079249779008
# seed is 171
# Accuracy Score on the test data is: 0.6165413533834586
# ROC-AUC Score on the test data is: 0.5753007417656328
# seed is 181
# Accuracy Score on the test data is: 0.6120300751879699
# ROC-AUC Score on the test data is: 0.5807775087436104
# seed is 191
# Accuracy Score on the test data is: 0.6270676691729323
# ROC-AUC Score on the test data is: 0.617750490026519
# seed is 201
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.5808543756485645
# seed is 211
# Accuracy Score on the test data is: 0.6030075187969924
# ROC-AUC Score on the test data is: 0.5893097351935124
# seed is 221
# Accuracy Score on the test data is: 0.6270676691729323
# ROC-AUC Score on the test data is: 0.6045485991006573
# seed is 231
# Accuracy Score on the test data is: 0.6180451127819548
# ROC-AUC Score on the test data is: 0.5993120412006611
# seed is 241
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.6168761289826665
# seed is 251
# Accuracy Score on the test data is: 0.6285714285714286
# ROC-AUC Score on the test data is: 0.5920673354087398
# seed is 261
# Accuracy Score on the test data is: 0.6045112781954888
# ROC-AUC Score on the test data is: 0.5913851416272724
# seed is 271
# Accuracy Score on the test data is: 0.631578947368421
# ROC-AUC Score on the test data is: 0.5963526653599294
# seed is 281
# Accuracy Score on the test data is: 0.6045112781954888
# ROC-AUC Score on the test data is: 0.5707944194627004
# seed is 291
# Accuracy Score on the test data is: 0.6225563909774436
# ROC-AUC Score on the test data is: 0.5912890579960798
# seed is 301
# Accuracy Score on the test data is: 0.6195488721804512
# ROC-AUC Score on the test data is: 0.597938045274607
# seed is 311
# Accuracy Score on the test data is: 0.6135338345864662
# ROC-AUC Score on the test data is: 0.5988412314078173
# seed is 321
# Accuracy Score on the test data is: 0.6105263157894737
# ROC-AUC Score on the test data is: 0.6095737730120298
# seed is 331
# Accuracy Score on the test data is: 0.6270676691729323
# ROC-AUC Score on the test data is: 0.6118893885237711
# seed is 341
# Accuracy Score on the test data is: 0.6285714285714286
# ROC-AUC Score on the test data is: 0.5958145970252509
# seed is 351
# Accuracy Score on the test data is: 0.6135338345864662
# ROC-AUC Score on the test data is: 0.5695837657096737
# seed is 361
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.6033091202582728
# seed is 371
# Accuracy Score on the test data is: 0.6240601503759399
# ROC-AUC Score on the test data is: 0.6059225950267113
# seed is 381
# Accuracy Score on the test data is: 0.6240601503759399
# ROC-AUC Score on the test data is: 0.6001479687920366
# seed is 391
# Accuracy Score on the test data is: 0.6180451127819548
# ROC-AUC Score on the test data is: 0.6021032706868058
# seed is 401
# Accuracy Score on the test data is: 0.6165413533834586
# ROC-AUC Score on the test data is: 0.6113897536415696
# seed is 411
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.5955839963103885
# seed is 421
# Accuracy Score on the test data is: 0.6225563909774436
# ROC-AUC Score on the test data is: 0.5738210538452669
# seed is 431
# Accuracy Score on the test data is: 0.6285714285714286
# ROC-AUC Score on the test data is: 0.6312310234828394
# seed is 441
# Accuracy Score on the test data is: 0.6090225563909775
# ROC-AUC Score on the test data is: 0.5761654944463661
# seed is 451
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.5911545409124102
# seed is 461
# Accuracy Score on the test data is: 0.6285714285714286
# ROC-AUC Score on the test data is: 0.6058265113955186
# seed is 471
# Accuracy Score on the test data is: 0.6210526315789474
# ROC-AUC Score on the test data is: 0.5681617279680233
# seed is 481
# Accuracy Score on the test data is: 0.6240601503759399
# ROC-AUC Score on the test data is: 0.6170682962450518
# seed is 491
# Accuracy Score on the test data is: 0.6195488721804512
# ROC-AUC Score on the test data is: 0.6067296975287291

# %%
report_df_highdim_data["auroc"].mean()
# Out:
# 0.5958437103655021

# %%
report_df_highdim_data["auroc"].std()
# Out:
# 0.015188779651819707

# %%
print(" The AUROC Performance of Best SVAE model on high-dimensional dataset over 50 seeds is: ")

print(str(round(report_df_highdim_data["auroc"].mean(),4)) + " +- " + str(round(report_df_highdim_data["auroc"].std(), 4)))
# Out:
#  The AUROC Performance of Best SVAE model on high-dimensional dataset over 50 seeds is:
# 0.5958 +- 0.0152

# %% [markdown]
# ### Correlation calculation between input variables and latent dimensions

# %%
current_dir = os.getcwd()
latent_folder = current_dir + "\latent_variable_correlations\\"
if not os.path.exists(latent_folder):
    os.mkdir(latent_folder)
    print("hyperparameter_reports directory is created under " + current_dir)
    
    
top_amount = 10
seed_lenght = len(seeds_list)    

latent_total_corr_list = []
#iterating over each latent variable
for f in range(eval_z.shape[1]):
    f_dict = {}
    #iterating over correlation list of each random seed
    for s, seed_corr in enumerate(seeds_corr_list):
        if s == 0:
            f_corr_seed1 = seed_corr[f].droplevel(level = 0).dropna()
            f_corr_seed1 = pd.DataFrame({'Variable':f_corr_seed1.index, 'AVG_abs_corr':f_corr_seed1.values})
            print("Top "+ str(top_amount) + " variables correlated with latent feature " + str(f+1) + " for random seed " + str(seeds_list[s]))
            f_corr_seed1_sorted = f_corr_seed1.sort_values(by = "AVG_abs_corr", ascending = False)[:top_amount]
            print(f_corr_seed1_sorted)
            f_corr_seed1_sorted.to_csv(os.path.join(latent_folder,"highdim_top_" + str(top_amount) + "_correlations_with_latent_variable_" + str(f+1) + "_"  + dt_string +  "_no_shuffling_random_seed" + str(seeds_list[s]) + ".txt"), sep = "\t", index = True)
            
        f_corr = seed_corr[f].droplevel(level = 0).dropna()
        
        for var_num in range(f_corr.size):
            if f_corr.index[var_num] not in f_dict:
                f_dict[f_corr.index[var_num]] = f_corr[var_num]
            else:
                f_dict[f_corr.index[var_num]] += f_corr[var_num]
        
    f_total_corr_df = pd.DataFrame.from_dict(f_dict, orient = "index").rename(columns = {0:"AVG_abs_corr"})
    latent_total_corr_list.append(f_total_corr_df)
    
        
        

for i in range(len(latent_total_corr_list)):
    latent_avg_corr = latent_total_corr_list[i] / seed_lenght 
    print("Top "+ str(top_amount) + " variables correlated with latent feature " + str(i+1) + " averaged in " + str(seed_lenght) + " random seeds.")
    latent_avg_corr_sorted = latent_avg_corr.sort_values(by = "AVG_abs_corr",ascending = False)[:top_amount]
    print(latent_avg_corr_sorted)
    
    latent_avg_corr_sorted.to_csv(os.path.join(latent_folder,"highdim_top_" + str(top_amount) + "_correlations_with_latent_variable_" + str(i+1) + "_"  + dt_string +  "_no_shuffling_" + str(seed_lenght) + " seeds" + ".txt"), sep = "\t", index = True)
# Out:
# Top 10 variables correlated with latent feature 1 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_N02AG      0.149808
# 1    ICD01_O80      0.134327
# 2  ATC10_R01AD      0.124578
# 3  ATC10_B03BA      0.124304
# 4  ATC10_R01AC      0.121373
# 5  ATC01_G02BB      0.115956
# 6    ICD10_Z53      0.114751
# 7    ICD01_D25      0.112630
# 8    ICD10_N71      0.112621
# 9    ICD01_Z37      0.111198
# Top 10 variables correlated with latent feature 2 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_N02BA      0.172295
# 1    ICD10_D07      0.129577
# 2    ICD01_R00      0.124491
# 3    ICD01_J90      0.120814
# 4    ICD10_J68      0.118486
# 5  ATC10_L01BC      0.118486
# 6    ICD10_R91      0.112542
# 7    ICD01_R10      0.111117
# 8    ICD10_B98      0.110924
# 9  ATC01_C10AB      0.110924
# Top 10 variables correlated with latent feature 3 for random seed 1
#     Variable  AVG_abs_corr
# 0  ICD10_E83      0.125471
# 1  ICD10_G00      0.122241
# 2  ICD01_D61      0.122241
# 3  ICD10_N17      0.122241
# 4  ICD10_G94      0.122241
# 5  ICD01_D69      0.122241
# 6  ICD01_D70      0.122241
# 7  ICD10_B95      0.122241
# 8  ICD10_G91      0.118232
# 9  ICD10_K11      0.109688
# Top 10 variables correlated with latent feature 4 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_G03FB      0.136306
# 1    ICD10_R15      0.130119
# 2    ICD10_S82      0.120683
# 3  ATC01_G03FB      0.109352
# 4  ATC01_C08DA      0.103923
# 5    ICD01_R15      0.103923
# 6    ICD01_K42      0.103923
# 7    ICD10_E34      0.103923
# 8    ICD01_L81      0.103923
# 9    ICD10_S00      0.101197
# Top 10 variables correlated with latent feature 5 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_O36      0.156800
# 1    ICD10_O12      0.124226
# 2    ICD10_N20      0.122631
# 3  ATC10_R05DB      0.120171
# 4    ICD01_D64      0.120086
# 5    ICD10_J17      0.116491
# 6    ICD10_O98      0.114549
# 7    ICD10_G53      0.114195
# 8  ATC01_S01AD      0.114195
# 9    ICD10_M01      0.114195
# Top 10 variables correlated with latent feature 6 for random seed 1
#           Variable  AVG_abs_corr
# 0      ATC01_B02AA      0.146895
# 1        ICD10_Z75      0.125950
# 2        ICD01_Z12      0.125950
# 3      ATC10_N05CF      0.118775
# 4        ICD10_Q07      0.114224
# 5      hospdays_01      0.112539
# 6  edu_lvl_missing      0.112475
# 7      ATC01_N03AG      0.111216
# 8      ATC01_C01AA      0.111133
# 9      ATC10_C01AA      0.111133
# Top 10 variables correlated with latent feature 7 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_D27      0.134556
# 1    ICD01_N47      0.127216
# 2     RA_years      0.124260
# 3  ATC10_S01FA      0.117058
# 4    ICD10_L73      0.112607
# 5    ICD01_T50      0.108963
# 6  ATC10_A12CA      0.108963
# 7  ATC01_N06DA      0.108963
# 8  ATC01_N06DX      0.108963
# 9    ICD10_R93      0.106691
# Top 10 variables correlated with latent feature 8 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_N84      0.132515
# 1  ATC10_D10AF      0.126450
# 2    ICD01_S73      0.120886
# 3    ICD10_H25      0.111463
# 4    ICD10_O46      0.110851
# 5    ICD10_F10      0.110518
# 6    ICD10_R00      0.107973
# 7  ATC10_J01CA      0.104068
# 8    ICD01_M65      0.104021
# 9    ICD10_Z11      0.101883
# Top 10 variables correlated with latent feature 9 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z04      0.130731
# 1    ICD10_Z02      0.130469
# 2  ATC01_G03AB      0.129663
# 3    ICD10_R41      0.124857
# 4  ATC10_L04AD      0.122630
# 5  ATC01_N06DA      0.113940
# 6  ATC01_N06DX      0.113940
# 7    ICD01_T50      0.113940
# 8  ATC10_A12CA      0.113940
# 9  ATC10_G03AB      0.111056
# Top 10 variables correlated with latent feature 10 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_B01AB      0.131775
# 1  ATC01_M01AE      0.117758
# 2    ICD10_M65      0.113812
# 3    ICD10_O24      0.111600
# 4    ICD01_M46      0.110734
# 5  ATC01_D07AC      0.110591
# 6  ATC10_A01AC      0.108314
# 7    ICD10_F41      0.106208
# 8  ATC10_R01AD      0.105473
# 9    ICD10_F19      0.104722
# Top 10 variables correlated with latent feature 11 for random seed 1
#        Variable  AVG_abs_corr
# 0     ICD10_G47      0.144582
# 1   ATC10_R05FA      0.126629
# 2     ICD10_O44      0.120909
# 3   ATC01_D11AX      0.120137
# 4   ATC01_G03AA      0.114435
# 5   ATC10_N02BE      0.108876
# 6   ATC01_D07AA      0.107146
# 7     ICD10_H02      0.106599
# 11    ICD01_L04      0.105925
# 12    ICD01_L53      0.105925
# Top 10 variables correlated with latent feature 12 for random seed 1
#       Variable  AVG_abs_corr
# 0  hospdays_10      0.138781
# 1    ICD10_N40      0.134455
# 2    ICD10_D47      0.129754
# 3    ICD10_M48      0.126985
# 4    ICD01_C90      0.123148
# 5  hosptime_10      0.121609
# 6    ICD10_S00      0.120389
# 7    ICD10_R76      0.120144
# 8    ICD10_E11      0.119712
# 9    ICD10_H81      0.118919
# Top 10 variables correlated with latent feature 13 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_N94      0.130670
# 1  ATC10_A06AA      0.120280
# 2  ATC10_N06AB      0.119178
# 3    ICD10_S64      0.110534
# 4  ATC10_C08DA      0.110526
# 5    ICD01_R69      0.108951
# 6  ATC10_M01CB      0.104841
# 7    ICD01_Z30      0.104515
# 8  ATC01_N06AB      0.104410
# 9    ICD10_F60      0.104368
# Top 10 variables correlated with latent feature 14 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_L04AA      0.136011
# 1    ICD10_H52      0.123498
# 2    ICD01_Z09      0.116492
# 3    ICD01_M62      0.114469
# 4    ICD10_S71      0.109061
# 5  ATC01_R05CA      0.107934
# 6    ICD01_M72      0.107934
# 7    ICD01_I65      0.107433
# 8    ICD01_I51      0.107433
# 9    ICD10_S10      0.102463
# Top 10 variables correlated with latent feature 15 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_K37      0.136182
# 1    ICD10_S30      0.118186
# 2    ICD10_O42      0.114535
# 3    ICD10_O35      0.112925
# 4  ATC10_G04CA      0.112047
# 5    ICD01_T18      0.109294
# 6    ICD01_J44      0.108840
# 7    ICD10_K58      0.106907
# 8  ATC10_A11HA      0.105484
# 9  ATC10_J04AC      0.104567
# Top 10 variables correlated with latent feature 16 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_S23      0.140134
# 1  ATC10_Y92FB      0.115854
# 2  ATC10_Y92GA      0.115854
# 3  ATC10_Y92HB      0.115854
# 4    ICD10_O70      0.102362
# 5    ICD10_S64      0.100703
# 6    ICD10_R52      0.100111
# 7    ICD10_M62      0.099865
# 8    ICD10_J39      0.099116
# 9  ATC10_G03AA      0.098374
# Top 10 variables correlated with latent feature 17 for random seed 1
#        Variable  AVG_abs_corr
# 0   ATC01_M01AE      0.123771
# 1     ICD10_I84      0.121991
# 2   ATC10_P01BC      0.117039
# 3  edu_lvl_>12y      0.116581
# 4   ATC10_Y92EA      0.114210
# 5   ATC10_D07XB      0.113264
# 6   ATC01_D07CA      0.113264
# 7     ICD10_C50      0.111797
# 8   ATC10_Y75KB      0.110898
# 9   ATC10_Y75KE      0.110898
# Top 10 variables correlated with latent feature 18 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_S35      0.145905
# 1    ICD10_Z87      0.125330
# 2    ICD10_Z64      0.115197
# 3    ICD10_O31      0.110329
# 4  ATC10_J01DD      0.109342
# 5    ICD10_A56      0.109342
# 6    ICD10_L42      0.109342
# 7    ICD01_G44      0.109311
# 8  ATC01_D07AB      0.108931
# 9    ICD01_H52      0.106391
# Top 10 variables correlated with latent feature 19 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_N07BB      0.141605
# 1    ICD01_D47      0.124461
# 2    ICD10_G01      0.122644
# 3  ATC10_C05AX      0.122644
# 4  ATC10_C05AE      0.121888
# 5  ATC10_G03AA      0.121544
# 6  ATC01_G03AA      0.117327
# 7    ICD01_R69      0.116487
# 8       crp_m0      0.114519
# 9    ICD10_I44      0.112677
# Top 10 variables correlated with latent feature 20 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M34      0.120707
# 1    ICD10_T63      0.114350
# 2    ICD01_M08      0.114038
# 3  ATC10_H05AA      0.108272
# 4    ICD01_R32      0.108042
# 5    ICD01_H65      0.100491
# 6    ICD10_D32      0.100491
# 7    ICD10_D43      0.100491
# 8    ICD10_K90      0.098933
# 9    ICD10_C34      0.098762
# Top 10 variables correlated with latent feature 21 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_A08AB      0.140258
# 1  ATC10_G04CB      0.136685
# 2    ICD10_K81      0.120894
# 3    ICD01_L82      0.120884
# 4    ICD10_U99      0.119326
# 5    ICD10_C60      0.119326
# 6  ATC10_Y92BA      0.113681
# 7    ICD01_S43      0.112921
# 8  ATC10_C01BD      0.111888
# 9  ATC10_Y92AD      0.111004
# Top 10 variables correlated with latent feature 22 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_N91      0.149863
# 1    ICD10_J84      0.122623
# 2  ATC01_A11EX      0.120988
# 3  ATC10_C01DA      0.118888
# 4  ATC01_L02BA      0.117242
# 5    ICD01_R10      0.114417
# 6    ICD01_C61      0.113282
# 7  ATC01_L02BB      0.111735
# 8    ICD01_N71      0.111691
# 9    ICD01_I65      0.108856
# Top 10 variables correlated with latent feature 23 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_J30      0.164738
# 1    ICD01_A09      0.134015
# 2  ATC01_C09CA      0.123173
# 3    ICD01_H25      0.122389
# 4  ATC01_N05CF      0.119237
# 5  ATC10_C09CA      0.119050
# 6  ATC01_L04AA      0.116168
# 7  ATC01_J01EA      0.115790
# 8    ICD10_E10      0.111684
# 9    ICD10_J01      0.108484
# Top 10 variables correlated with latent feature 24 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M67      0.117003
# 1    ICD01_K52      0.106585
# 2    ICD10_Z99      0.100078
# 3    ICD10_L29      0.099119
# 4    ICD10_L73      0.097201
# 5    ICD10_C64      0.096062
# 6    ICD01_I73      0.095282
# 7    ICD10_F29      0.094903
# 8    ICD10_R60      0.093542
# 9  ATC01_N02BE      0.092255
# Top 10 variables correlated with latent feature 25 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_K58      0.122931
# 1  ATC10_D06BB      0.119822
# 2    ICD10_K80      0.113101
# 3    ICD01_S66      0.112359
# 4    ICD01_L63      0.105339
# 5  ATC01_G02BA      0.103430
# 6    ICD01_Z27      0.103142
# 7    ICD10_M47      0.102788
# 8    ICD10_L90      0.102194
# 9    ICD10_K40      0.101514
# Top 10 variables correlated with latent feature 26 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_P01BA      0.120984
# 1    ICD01_R04      0.119655
# 2    ICD01_S60      0.118530
# 3    ICD10_O81      0.115208
# 4  ATC10_C07AB      0.112785
# 5     tjc28_m0      0.112480
# 6  ATC01_G03CA      0.106116
# 7    ICD01_M17      0.105305
# 8    ICD01_Z22      0.104117
# 9    ICD10_N83      0.103848
# Top 10 variables correlated with latent feature 27 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_L90      0.111710
# 1    ICD01_M60      0.111710
# 2  ATC01_A06AD      0.107205
# 3    ICD01_L57      0.106396
# 4    ICD10_J38      0.105883
# 5    ICD10_A46      0.105842
# 6    ICD01_H52      0.105617
# 7    ICD10_L85      0.105513
# 8    ICD10_L01      0.103796
# 9    ICD01_Z29      0.103018
# Top 10 variables correlated with latent feature 28 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_J84      0.126925
# 1    ICD10_R19      0.117638
# 2  ATC01_A11EX      0.116810
# 3  ATC10_G03CX      0.114306
# 4    ICD10_H65      0.112739
# 5  ATC10_D07AB      0.111530
# 6    ICD10_J43      0.109313
# 7    ICD10_R60      0.108461
# 8    ICD10_G91      0.105537
# 9    ICD10_N46      0.105051
# Top 10 variables correlated with latent feature 29 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z04      0.134571
# 1  ATC01_B01AA      0.126927
# 2  ATC01_N03AF      0.126713
# 3  ATC01_N02AE      0.124145
# 4    ICD01_R39      0.115063
# 5    ICD01_O67      0.114150
# 6    ICD01_Z37      0.114150
# 7    ICD01_R31      0.112301
# 8    ICD01_J04      0.110943
# 9    ICD10_N70      0.110943
# Top 10 variables correlated with latent feature 30 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_N05CM      0.135116
# 1    ICD10_D27      0.121987
# 2    ICD01_A08      0.119567
# 3    ICD10_K40      0.113482
# 4  ATC01_P01BB      0.111453
# 5    ICD10_S92      0.110248
# 6  ATC01_H01BA      0.109014
# 7    ICD10_F06      0.108942
# 8    ICD01_T51      0.108420
# 9    ICD10_R77      0.105408
# Top 10 variables correlated with latent feature 31 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M24      0.142967
# 1  ATC10_H01CC      0.134080
# 2    ICD01_H52      0.124135
# 3    ICD10_I45      0.120831
# 4    ICD10_C77      0.116912
# 5    ICD10_C43      0.116912
# 6    ICD10_J93      0.116912
# 7    ICD10_S81      0.116912
# 8    ICD10_M08      0.114858
# 9    ICD10_H04      0.114591
# Top 10 variables correlated with latent feature 32 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_G03FA      0.120848
# 1    ICD10_Z31      0.111663
# 2  ATC01_L04AX      0.111554
# 3  ATC10_G04BD      0.104093
# 4    ICD01_Z26      0.102686
# 5    ICD01_M07      0.100659
# 6  ATC10_N02CC      0.100220
# 7  ATC01_N02CC      0.097504
# 8  ATC10_B01AB      0.096326
# 9    ICD10_H65      0.096013
# Top 10 variables correlated with latent feature 33 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_R10      0.145855
# 1    ICD01_J34      0.140176
# 2    ICD10_M45      0.140176
# 3    ICD10_H69      0.140176
# 4    ICD10_T51      0.127844
# 5    ICD01_M46      0.125046
# 6    ICD10_D38      0.123751
# 7  ATC01_G03FB      0.120357
# 8    ICD10_S53      0.116778
# 9    ICD10_J35      0.110846
# Top 10 variables correlated with latent feature 34 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_R06AE      0.146051
# 1    ICD01_Z72      0.121836
# 2    ICD01_M21      0.117987
# 3    ICD01_R05      0.116795
# 4  ATC01_N02AB      0.116284
# 5  ATC01_G03DC      0.116057
# 6    ICD10_N48      0.115380
# 7  ATC01_N05CD      0.114530
# 8  ATC10_P02CA      0.109791
# 9  ATC01_S01CA      0.109325
# Top 10 variables correlated with latent feature 35 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_S83      0.120566
# 1    ICD01_K58      0.114101
# 2  ATC10_G03FB      0.110058
# 3    ICD10_J39      0.104029
# 4    ICD10_K20      0.100628
# 5  ATC01_N02BA      0.100327
# 6  ATC10_D07AA      0.099932
# 7    ICD10_Z09      0.098079
# 8  ATC01_N05CF      0.097023
# 9  ATC10_N02BA      0.095527
# Top 10 variables correlated with latent feature 36 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M18      0.126899
# 1    ICD10_K62      0.118015
# 2    ICD10_T50      0.112753
# 3  ATC10_A11EA      0.110731
# 4    ICD01_H65      0.105638
# 5    ICD10_D43      0.105638
# 6    ICD10_D32      0.105638
# 7  ATC01_S03CA      0.100977
# 8    ICD10_O99      0.100360
# 9    ICD10_O80      0.099596
# Top 10 variables correlated with latent feature 37 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_M05BX      0.141910
# 1    ICD10_E03      0.133982
# 2    ICD10_T18      0.130922
# 3    ICD01_S70      0.126034
# 4    ICD10_H33      0.121038
# 5    ICD10_I95      0.119223
# 6  ATC01_M01BX      0.116114
# 7    ICD10_H54      0.114601
# 8    ICD10_D24      0.113025
# 9    ICD10_K11      0.111359
# Top 10 variables correlated with latent feature 38 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_I48      0.119569
# 1    ICD10_G54      0.114691
# 2    ICD10_S93      0.112375
# 3    ICD10_T14      0.111039
# 4    ICD10_B37      0.110067
# 5    ICD01_I48      0.107557
# 6  ATC10_B02AA      0.107186
# 7    ICD01_F63      0.106134
# 8    ICD10_F63      0.106134
# 9  ATC10_C07AG      0.106134
# Top 10 variables correlated with latent feature 39 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_C02CA      0.147173
# 1       haq_m0      0.139498
# 2    ICD10_E14      0.132004
# 3    ICD01_L72      0.124238
# 4    ICD10_D04      0.120804
# 5  ATC01_C03DB      0.119223
# 6  ATC01_G02BA      0.118715
# 7    ICD10_B95      0.118031
# 8    ICD01_D70      0.118031
# 9    ICD10_G00      0.118031
# Top 10 variables correlated with latent feature 40 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_R05      0.149172
# 1  ATC01_J07AE      0.128031
# 2     early_ra      0.122723
# 3  ATC10_S01GX      0.120247
# 4  ATC10_N06AX      0.118780
# 5    ICD10_F60      0.115531
# 6    ICD10_K30      0.115037
# 7  ATC01_L04AX      0.113051
# 8     RA_years      0.112580
# 9  ATC01_M05BB      0.109442
# Top 10 variables correlated with latent feature 41 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_E06      0.144580
# 1    ICD10_I73      0.132285
# 2  ATC10_A11CC      0.126110
# 3    ICD10_E05      0.119059
# 4  ATC10_N02BA      0.112122
# 5    ICD01_N35      0.105979
# 6  ATC01_P02CA      0.105979
# 7    ICD01_R13      0.103296
# 8    ICD10_M43      0.102717
# 9    ICD01_R31      0.100066
# Top 10 variables correlated with latent feature 42 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_S01BC      0.116916
# 1    ICD01_N83      0.115310
# 2    ICD10_N60      0.114135
# 3  ATC01_C05AA      0.111748
# 4    ICD01_E06      0.107910
# 5    ICD01_I15      0.107910
# 6    ICD10_E06      0.106824
# 7  ATC10_N04BC      0.104217
# 8    ICD10_H90      0.102773
# 9    ICD10_G43      0.100548
# Top 10 variables correlated with latent feature 43 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_Y92AD      0.142484
# 1  ATC01_N06AA      0.133531
# 2  ATC01_Y92AD      0.126533
# 3  ATC10_Y92BA      0.122152
# 4  ATC10_A10AE      0.120809
# 5  ATC01_A10BJ      0.120145
# 6  ATC10_J01FA      0.119210
# 7    ICD10_E10      0.118123
# 8  ATC01_A10AB      0.110030
# 9    ICD10_S72      0.108430
# Top 10 variables correlated with latent feature 44 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_J01FF      0.137475
# 1    ICD01_R35      0.119338
# 2    ICD10_I71      0.116320
# 3    ICD01_F42      0.113649
# 4    ICD10_K08      0.107720
# 5    ICD10_K05      0.107720
# 6  ATC01_S01AE      0.107720
# 7    ICD01_M23      0.107591
# 8    ICD10_H36      0.104838
# 9    ICD01_Z85      0.104275
# Top 10 variables correlated with latent feature 45 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_K90      0.116233
# 1    ICD01_O48      0.115989
# 2    ICD01_E14      0.115655
# 3    ICD01_Z91      0.113159
# 4    ICD10_M80      0.110100
# 5    ICD01_O61      0.109318
# 6    ICD10_J11      0.107761
# 7    ICD01_S30      0.107761
# 8  ATC01_M01CB      0.107761
# 9    ICD01_G25      0.107761
# Top 10 variables correlated with latent feature 46 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z12      0.142189
# 1  ATC01_D01AC      0.136539
# 2    ICD10_S50      0.128146
# 3    ICD01_B34      0.128146
# 4    ICD10_L29      0.126361
# 5  ATC01_M04AC      0.120687
# 6    ICD10_S90      0.119970
# 7    ICD01_K31      0.118181
# 8  ATC10_N07AX      0.118181
# 9    ICD10_J14      0.118181
# Top 10 variables correlated with latent feature 47 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z21      0.149091
# 1    ICD10_N97      0.143177
# 2  ATC10_R03BB      0.134681
# 3  ATC01_N02BE      0.130265
# 4    ICD10_N88      0.129489
# 5  ATC10_D06BX      0.128997
# 6  ATC10_Y92AD      0.128069
# 7  ATC10_G04BX      0.121863
# 8    ICD10_Q87      0.109486
# 9    ICD01_Q87      0.109486
# Top 10 variables correlated with latent feature 48 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_D04      0.131396
# 1    ICD01_T85      0.121917
# 2    ICD01_S51      0.121917
# 3    ICD01_I80      0.109675
# 4    ICD10_A16      0.108415
# 5  ATC10_N05AD      0.108415
# 6    ICD10_M43      0.103996
# 7    ICD01_R06      0.103203
# 8    ICD10_J39      0.102140
# 9  ATC01_L02BA      0.102123
# Top 10 variables correlated with latent feature 49 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_L81      0.138720
# 1  ATC10_L02AE      0.127589
# 2  ATC10_B01AF      0.126424
# 3  ATC01_G03AA      0.120457
# 4  ATC01_A01AA      0.118713
# 5    ICD01_S10      0.117285
# 6    ICD10_T50      0.113154
# 7  ATC10_A12CA      0.109791
# 8  ATC01_N06DX      0.109791
# 9  ATC01_N06DA      0.109791
# Top 10 variables correlated with latent feature 50 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_N01BB      0.133037
# 1    ICD01_G80      0.115356
# 2    ICD10_E80      0.115356
# 3    ICD10_K83      0.115356
# 4    ICD10_K82      0.114072
# 5    ICD01_R06      0.111920
# 6    ICD10_B30      0.108922
# 7    ICD10_Z27      0.108580
# 8    ICD10_I44      0.108032
# 9  ATC01_J01CE      0.103560
# Top 10 variables correlated with latent feature 51 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_G54      0.128155
# 1  ATC10_L01BC      0.104340
# 2    ICD10_J68      0.104340
# 3  ATC01_A07DA      0.102627
# 4    ICD10_H50      0.102539
# 5  ATC01_Y92GB      0.101572
# 6  ATC01_Y92HA      0.101572
# 7  ATC01_Y92FA      0.101572
# 8    ICD10_M80      0.101096
# 9  ATC01_S01BC      0.100807
# Top 10 variables correlated with latent feature 52 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_E11      0.132213
# 1    ICD10_M77      0.122072
# 2    ICD10_M51      0.115876
# 3    ICD01_G47      0.110149
# 4    ICD01_S30      0.109819
# 5    ICD01_G25      0.109819
# 6  ATC01_M01CB      0.109819
# 7    ICD10_J11      0.109819
# 8    ICD01_A46      0.108396
# 9    ICD01_S52      0.107572
# Top 10 variables correlated with latent feature 53 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_N02AC      0.140586
# 1    ICD10_Z11      0.130445
# 2  ATC10_R01AC      0.117841
# 3    ICD10_Z41      0.116892
# 4    ICD10_E65      0.116892
# 5    ICD10_N97      0.114082
# 6  ATC10_A02BD      0.112704
# 7  ATC01_D02AE      0.110455
# 8    ICD01_M53      0.108293
# 9    ICD10_K56      0.105289
# Top 10 variables correlated with latent feature 54 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_X75QA      0.143874
# 1    ICD01_K44      0.125347
# 2    ICD10_A87      0.120087
# 3    ICD10_S72      0.118764
# 4    ICD10_I20      0.115084
# 5    ICD10_M35      0.109876
# 6  ATC10_Y75BE      0.109292
# 7    ICD10_M96      0.108780
# 8    ICD01_B37      0.108757
# 9  ATC10_M05BA      0.105786
# Top 10 variables correlated with latent feature 55 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_X75QA      0.189913
# 1    ICD10_M96      0.160304
# 2    ICD10_I50      0.153943
# 3    ICD01_I25      0.142263
# 4    ICD01_K52      0.141613
# 5  ATC01_C01DA      0.136266
# 6  ATC10_S01XA      0.135513
# 7  ATC10_Y75KB      0.135165
# 8  ATC10_Y75KE      0.135165
# 9  ATC10_C03CA      0.132857
# Top 10 variables correlated with latent feature 56 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_R10      0.147655
# 1    ICD01_Z01      0.132387
# 2    ICD10_N95      0.123723
# 3    ICD10_H92      0.123674
# 4    ICD10_H66      0.123014
# 5  ATC01_J01FF      0.120232
# 6    ICD10_H72      0.119598
# 7  ATC01_A02BD      0.116554
# 8  ATC01_N02AB      0.114778
# 9    ICD10_J34      0.111399
# Top 10 variables correlated with latent feature 57 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_A12CB      0.137016
# 3    ICD01_L29      0.137016
# 1    ICD01_N72      0.137016
# 2  ATC01_S01CA      0.137016
# 4    ICD01_B34      0.128435
# 5    ICD10_S50      0.128435
# 6    ICD10_K09      0.107508
# 7    ICD01_K07      0.107508
# 8  ATC10_R06AA      0.106885
# 9    ICD10_D14      0.106059
# Top 10 variables correlated with latent feature 58 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_G04CB      0.137239
# 1          age      0.134414
# 2  hospdays_10      0.134149
# 3  ATC10_M05BX      0.127919
# 4  ATC10_M01AH      0.120067
# 5  ATC01_N06AX      0.117255
# 6    ICD01_T81      0.117072
# 7  ATC01_N05BA      0.114307
# 8    ICD10_K63      0.113623
# 9    ICD10_L01      0.113327
# Top 10 variables correlated with latent feature 59 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M08      0.152580
# 1    ICD01_Z26      0.128991
# 2    ICD10_M25      0.121199
# 3  ATC01_A03FA      0.116040
# 4  ATC10_N05CH      0.113833
# 5    ICD10_I95      0.099265
# 6    ICD01_L70      0.098640
# 7  ATC01_D10AD      0.098640
# 8    ICD01_D23      0.098640
# 9    ICD01_L92      0.098640
# Top 10 variables correlated with latent feature 60 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M08      0.126234
# 1  ATC01_L02BG      0.123583
# 2    ICD10_R32      0.119890
# 3    ICD10_C50      0.118257
# 4    ICD01_M24      0.116676
# 5    ICD01_D84      0.116676
# 6    ICD01_K76      0.116676
# 7    ICD10_S09      0.114823
# 8  ATC10_G02CX      0.114823
# 9    ICD01_L71      0.114823
# Top 10 variables correlated with latent feature 61 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_I20      0.154964
# 1    ICD01_H01      0.136323
# 2    ICD01_I20      0.133112
# 3    ICD10_R52      0.127107
# 4    ICD10_M75      0.119286
# 5    ICD10_N84      0.118249
# 6    ICD10_Z00      0.111520
# 7  ATC10_J07BC      0.110700
# 8  ATC01_Y92AC      0.110086
# 9    ICD10_Z33      0.103629
# Top 10 variables correlated with latent feature 62 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z33      0.138026
# 1    ICD10_O81      0.131339
# 2    ICD10_O68      0.128417
# 3  ATC01_G03AA      0.127604
# 4  ATC01_N06AB      0.118076
# 5    ICD10_D33      0.116073
# 6    ICD10_D11      0.116073
# 7    ICD10_L20      0.114016
# 8    ICD10_F39      0.113987
# 9    ICD01_O41      0.113987
# Top 10 variables correlated with latent feature 63 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z96      0.127576
# 1          age      0.126288
# 2    ICD10_S24      0.123474
# 3  ATC01_P01AB      0.121833
# 4    ICD10_O42      0.119632
# 5    ICD10_E73      0.117778
# 6    ICD10_M51      0.117665
# 7  ATC10_R06AA      0.115307
# 8    ICD01_A04      0.113100
# 9    ICD10_R56      0.111874
# Top 10 variables correlated with latent feature 64 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_C10AX      0.144551
# 1    ICD10_O03      0.133791
# 2    ICD10_C34      0.133708
# 3    ICD10_J99      0.125206
# 4    ICD10_N18      0.124078
# 5    ICD10_L82      0.122067
# 6    ICD10_M24      0.122060
# 7    ICD10_M67      0.120984
# 8    ICD10_T93      0.117688
# 9    ICD10_Z73      0.116280
# Top 10 variables correlated with latent feature 65 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_C03CA      0.126989
# 1  ATC01_N05CM      0.125569
# 2  hosptime_10      0.120585
# 3    ICD01_Z95      0.117479
# 4  ATC10_C10AX      0.117322
# 5  ATC10_D11AH      0.116209
# 6    ICD10_N96      0.116209
# 7    ICD10_O84      0.116209
# 8  ATC10_H02AB      0.113505
# 9    ICD10_M96      0.112141
# Top 10 variables correlated with latent feature 66 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_R53      0.130700
# 1    ICD01_Z64      0.125427
# 2    ICD10_I15      0.123492
# 3    ICD10_J46      0.122677
# 4    ICD01_R70      0.122050
# 5    ICD10_O70      0.114678
# 6    ICD01_F33      0.111764
# 7  ATC10_L01BA      0.111710
# 8    ICD01_M35      0.111600
# 9  ATC10_H03BA      0.107474
# Top 10 variables correlated with latent feature 67 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_D06BX      0.135107
# 1  ATC10_N03AX      0.122369
# 2    ICD10_A05      0.119986
# 3  ATC01_A01AD      0.115265
# 4    ICD10_G56      0.115038
# 5    ICD01_G44      0.113036
# 6    ICD10_N95      0.112690
# 7  ATC01_N03AX      0.111923
# 8    ICD01_F84      0.111893
# 9    ICD01_S22      0.109327
# Top 10 variables correlated with latent feature 68 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_A04AD      0.145508
# 1  ATC10_A03FA      0.130486
# 2    ICD01_T85      0.129592
# 3    ICD01_S51      0.129592
# 4    ICD10_K90      0.126644
# 5    ICD01_L72      0.126423
# 6    ICD01_M08      0.119192
# 7  ATC01_M01AC      0.117891
# 8  ATC01_C05BA      0.115712
# 9    ICD01_M19      0.113216
# Top 10 variables correlated with latent feature 69 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_S22      0.131407
# 1    ICD10_D07      0.120610
# 2  ATC01_R06AE      0.117540
# 3  ATC01_M03BB      0.116620
# 4    ICD10_R94      0.115776
# 5    ICD10_L28      0.113018
# 6    ICD01_L30      0.111415
# 7    ICD10_O13      0.111007
# 8  ATC10_H05AA      0.109572
# 9  ATC10_X75QA      0.108775
# Top 10 variables correlated with latent feature 70 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_D51      0.128952
# 1  ATC10_S01AE      0.120377
# 2    ICD01_K51      0.119811
# 3  ATC01_D06BX      0.116925
# 4    ICD10_H16      0.116584
# 5  ATC01_L04AB      0.111871
# 6  ATC10_R06AA      0.111606
# 8    ICD01_Z53      0.108113
# 7  ATC10_X75EH      0.108113
# 9    ICD01_O48      0.108043
# Top 10 variables correlated with latent feature 71 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z22      0.141625
# 1    ICD01_R00      0.135523
# 2  ATC01_A04AA      0.129199
# 3    ICD01_M19      0.116612
# 4  ATC01_G03XC      0.114731
# 5    ICD01_S92      0.114731
# 6    ICD01_K31      0.110831
# 7  ATC10_N07AX      0.110831
# 8    ICD10_J14      0.110831
# 9    ICD01_E07      0.110831
# Top 10 variables correlated with latent feature 72 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_R39      0.119654
# 1    ICD10_J30      0.114918
# 2    ICD10_N32      0.113540
# 3  ATC01_A02BD      0.112576
# 4  ATC01_D07AD      0.112092
# 5    ICD01_I47      0.107727
# 6  ATC01_J01EA      0.107727
# 7  ATC10_J01CE      0.103490
# 8    ICD01_M65      0.096115
# 9  ATC01_L04AA      0.095138
# Top 10 variables correlated with latent feature 73 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M32      0.127742
# 1  ATC10_J04AB      0.111201
# 2    ICD10_M96      0.110367
# 3    ICD01_Z01      0.106103
# 4  ATC01_C10AB      0.104330
# 5    ICD10_B98      0.104330
# 6    ICD10_K31      0.103683
# 7  ATC10_R06AE      0.095980
# 8    ICD10_J30      0.095393
# 9    ICD01_M53      0.089597
# Top 10 variables correlated with latent feature 74 for random seed 1
#               Variable  AVG_abs_corr
# 0            ICD10_M77      0.156467
# 1  country_Scandinavia      0.135883
# 2            ICD10_E76      0.125836
# 3            ICD10_O35      0.123252
# 4            ICD10_O20      0.121755
# 5            ICD01_M05      0.115808
# 6            ICD01_M24      0.113174
# 7            ICD01_D84      0.113174
# 8            ICD01_K76      0.113174
# 9            ICD10_R12      0.113034
# Top 10 variables correlated with latent feature 75 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_L27      0.125535
# 1    ICD10_D06      0.119576
# 2  ATC10_B01AB      0.117558
# 3    ICD10_M84      0.117242
# 4    ICD10_Z13      0.117155
# 5    ICD10_H02      0.111996
# 6    ICD10_R19      0.107509
# 7    ICD01_H18      0.106399
# 8  ATC10_A06AG      0.106335
# 9  ATC10_M05BB      0.104306
# Top 10 variables correlated with latent feature 76 for random seed 1
#       Variable  AVG_abs_corr
# 0          age      0.129452
# 1    ICD10_O26      0.129451
# 2    ICD10_E83      0.115005
# 3    ICD01_O80      0.112457
# 4  ATC10_G03GA      0.112355
# 5    ICD10_S33      0.112221
# 6    ICD10_S53      0.111811
# 7    ICD01_Z08      0.108995
# 8    ICD10_Z97      0.105298
# 9    ICD10_R14      0.104690
# Top 10 variables correlated with latent feature 77 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_F41      0.125071
# 1  ATC10_G01AF      0.116593
# 2    ICD10_N99      0.115949
# 3    ICD10_O65      0.113226
# 4  ATC01_M05BB      0.112276
# 5    ICD01_J18      0.108374
# 6    ICD10_S53      0.107316
# 7    ICD01_M20      0.107164
# 8    ICD10_H61      0.105396
# 9    ICD01_T83      0.102962
# Top 10 variables correlated with latent feature 78 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_D22      0.131561
# 1  ATC01_A03FA      0.121893
# 2  ATC10_B03AA      0.121501
# 3    ICD10_B34      0.119314
# 4    ICD10_J17      0.117513
# 5    ICD10_R35      0.114173
# 6    ICD10_Z39      0.113895
# 7  ATC10_G01AA      0.112762
# 8    ICD01_R70      0.112291
# 9  ATC10_R01BA      0.109606
# Top 10 variables correlated with latent feature 79 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_S83      0.171888
# 1    ICD10_R10      0.119342
# 2    ICD10_R30      0.114592
# 4  ATC01_G03BA      0.110833
# 3  ATC10_G03BA      0.110833
# 5  ATC10_A06AB      0.107209
# 6    ICD10_O31      0.107088
# 7    ICD10_Z71      0.102340
# 8  ATC01_M01AX      0.100993
# 9  ATC10_S02BA      0.100690
# Top 10 variables correlated with latent feature 80 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z97      0.129524
# 1    ICD01_M54      0.127999
# 2    ICD10_Z80      0.124941
# 3    ICD10_M05      0.122251
# 4    ICD10_I60      0.121229
# 5    ICD01_D18      0.118825
# 6    ICD10_M84      0.115281
# 7  ATC01_R06AA      0.112749
# 8    ICD10_T15      0.110095
# 9  ATC10_N02AX      0.106307
# Top 10 variables correlated with latent feature 81 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_E73      0.134675
# 1    ICD10_Z96      0.126506
# 2    ICD10_M06      0.122177
# 3    ICD10_K14      0.120265
# 4    ICD10_Z98      0.119373
# 5  ATC10_D07CC      0.116176
# 6    ICD10_H47      0.115397
# 7    ICD10_E78      0.114891
# 8    ICD01_S13      0.114701
# 9    ICD01_J33      0.114701
# Top 10 variables correlated with latent feature 82 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_G03AC      0.148386
# 1       pga_m0      0.127713
# 2    ICD01_A04      0.121155
# 3  ATC01_J07BA      0.116590
# 4    ICD10_T14      0.110796
# 5  ATC10_A07AA      0.110588
# 6  ATC10_N06BA      0.110033
# 7    ICD10_I83      0.109679
# 8  ATC10_A11CC      0.109463
# 9  ATC01_G03AA      0.106158
# Top 10 variables correlated with latent feature 83 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_J31      0.127132
# 2    ICD10_E16      0.123283
# 1    ICD01_I70      0.123283
# 3    ICD01_M05      0.118293
# 4  ATC10_A12AA      0.114901
# 5    ICD10_Z04      0.114423
# 6    ICD10_B99      0.112241
# 7    ICD10_T51      0.108381
# 8    ICD10_K29      0.107441
# 9  ATC01_N03AF      0.106828
# Top 10 variables correlated with latent feature 84 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_M76      0.132345
# 3  ATC01_N06BX      0.132345
# 1  ATC10_D09AA      0.132345
# 2  ATC10_N06BX      0.132345
# 4  ATC01_C05BA      0.130695
# 5    ICD01_T93      0.118749
# 6  ATC01_S01XA      0.118251
# 7  ATC01_R06AA      0.115345
# 8  ATC10_S01XA      0.113875
# 9  ATC01_J01FA      0.111957
# Top 10 variables correlated with latent feature 85 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z80      0.111958
# 1    ICD10_H61      0.108988
# 2    ICD10_S67      0.102198
# 3    ICD10_Z40      0.101662
# 4  ATC10_R06AX      0.101524
# 5  ATC10_S02AA      0.101170
# 6    ICD10_H91      0.100833
# 7    ICD10_B37      0.100553
# 8  ATC10_J01MA      0.099782
# 9    ICD01_R56      0.099393
# Top 10 variables correlated with latent feature 86 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_K31      0.126505
# 3    ICD10_J14      0.126505
# 1  ATC10_N07AX      0.126505
# 2    ICD01_E07      0.126505
# 4  ATC10_L02AE      0.121391
# 5  ATC10_N05CM      0.118749
# 6  ATC10_R05FB      0.114849
# 7  ATC10_R01AD      0.113820
# 8  ATC01_M02AA      0.112913
# 9  ATC10_N02CC      0.112457
# Top 10 variables correlated with latent feature 87 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_D07AC      0.134431
# 5  ATC01_A09AA      0.125590
# 7  ATC10_Y90LC      0.125590
# 6  ATC10_Y92BB      0.125590
# 1    ICD10_R63      0.125590
# 4  ATC01_Y92FB      0.125590
# 3  ATC01_Y90LC      0.125590
# 2  ATC10_Y92GB      0.125590
# 8  ATC10_G03DC      0.118996
# 9  ATC10_C01CA      0.116468
# Top 10 variables correlated with latent feature 88 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_E87      0.126264
# 1  ATC10_Y92FB      0.123779
# 2  ATC10_Y92GA      0.123779
# 3  ATC10_Y92HB      0.123779
# 4    ICD10_M79      0.122683
# 5  ATC01_C03DB      0.121234
# 6    ICD10_R59      0.116467
# 7    ICD10_J46      0.115441
# 8    ICD10_M95      0.113237
# 9    ICD10_H57      0.112500
# Top 10 variables correlated with latent feature 89 for random seed 1
#               Variable  AVG_abs_corr
# 0  edu_lvl_09y_or_less      0.141198
# 1           workloss10      0.139331
# 2          ATC10_C08CA      0.136772
# 3            ICD01_Z26      0.133904
# 4          ATC10_G03CX      0.117572
# 5      edu_lvl_missing      0.115223
# 6            ICD10_K04      0.113196
# 7          ATC01_C03DA      0.112955
# 8            ICD01_M24      0.111199
# 9            ICD01_D84      0.111199
# Top 10 variables correlated with latent feature 90 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_N18      0.170860
# 1  ATC10_V03AE      0.147679
# 2  ATC01_V03AE      0.147679
# 3  ATC10_A02AH      0.147679
# 4    ICD10_R80      0.147679
# 5    ICD10_H19      0.143886
# 6  ATC10_X75QA      0.133914
# 7  ATC10_S01FA      0.131428
# 8    ICD10_J99      0.129519
# 9    ICD01_M08      0.129422
# Top 10 variables correlated with latent feature 91 for random seed 1
#           Variable  AVG_abs_corr
# 0  prednisolone_m0      0.135990
# 1        ICD01_M23      0.119986
# 2        ICD01_K43      0.119909
# 3        ICD10_M02      0.118361
# 4        ICD01_L90      0.116746
# 5        ICD01_M60      0.116746
# 6        ICD10_S51      0.116686
# 7        ICD10_E66      0.113450
# 8      ATC10_D07AA      0.112733
# 9      ATC10_N03AE      0.106971
# Top 10 variables correlated with latent feature 92 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_L63      0.133781
# 1    ICD01_J32      0.121224
# 2  ATC01_A03AX      0.118517
# 3    ICD10_Z80      0.116364
# 4    ICD10_D22      0.111329
# 5    ICD10_I70      0.110182
# 6  ATC01_G03FB      0.109649
# 7  ATC01_P01BB      0.109572
# 8    ICD10_M43      0.109568
# 9  ATC10_G01AF      0.109397
# Top 10 variables correlated with latent feature 93 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M25      0.135887
# 1    ICD10_N63      0.129237
# 2    ICD10_R31      0.122180
# 3    ICD10_J46      0.120766
# 4  ATC10_J07BK      0.116595
# 5  ATC01_A01AA      0.116483
# 6  ATC10_R06AE      0.107477
# 7  ATC10_M04AC      0.106155
# 8    ICD10_H16      0.105339
# 9    ICD10_Z92      0.102307
# Top 10 variables correlated with latent feature 94 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_C90      0.136357
# 3    ICD01_L71      0.120876
# 4  ATC01_G02CX      0.120876
# 1  ATC10_G02CX      0.120876
# 2    ICD10_S09      0.120876
# 5  ATC01_G04BX      0.120682
# 6    ICD10_L28      0.118524
# 7  ATC10_A10BH      0.114735
# 8    ICD10_R32      0.113087
# 9    ICD10_M60      0.111018
# Top 10 variables correlated with latent feature 95 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_C09AA      0.120854
# 1    ICD10_D10      0.117684
# 2    ICD10_J04      0.114537
# 3    ICD10_H69      0.111385
# 4    ICD01_J34      0.111385
# 5    ICD10_M45      0.111385
# 6  ATC01_J02AC      0.110526
# 7    ICD10_K29      0.110244
# 8    ICD10_H50      0.109268
# 9  ATC01_D07AA      0.106105
# Top 10 variables correlated with latent feature 96 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_I44      0.130316
# 1  ATC10_D01AE      0.127630
# 2  ATC01_C07AA      0.121609
# 3    ICD10_L82      0.115774
# 4    ICD10_R52      0.110946
# 5    ICD01_R51      0.109697
# 6  ATC10_N01BX      0.109675
# 7  ATC10_S02CA      0.105941
# 8  ATC10_C07AA      0.102479
# 9    ICD10_C53      0.101357
# Top 10 variables correlated with latent feature 97 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_L29      0.167298
# 1    ICD01_M53      0.133057
# 2  ATC10_M01AE      0.129948
# 3  ATC10_D07AB      0.122292
# 4  ATC10_N05CM      0.116310
# 5    ICD10_R56      0.115323
# 6  ATC01_A05AA      0.114334
# 7  ATC10_A05AA      0.114334
# 8    ICD10_H06      0.111654
# 9  ATC01_D01AC      0.111571
# Top 10 variables correlated with latent feature 98 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_Z04      0.142042
# 1    ICD01_O26      0.138561
# 2    ICD01_O48      0.137792
# 3    ICD10_I30      0.136669
# 4  ATC01_A12AX      0.128824
# 5    ICD01_S10      0.126820
# 6    ICD10_R93      0.126036
# 7  ATC10_M05BB      0.118673
# 8    ICD10_J18      0.114894
# 9  ATC10_N05AA      0.113382
# Top 10 variables correlated with latent feature 99 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_I84      0.156461
# 1    ICD10_Q83      0.151314
# 2    ICD10_Q79      0.151314
# 3    ICD01_N61      0.151314
# 4  ATC01_D07CA      0.129512
# 5  ATC10_D07XB      0.129512
# 6  ATC10_R05FB      0.127581
# 7    ICD10_S66      0.123877
# 8  ATC01_D11AX      0.120953
# 9    ICD01_D18      0.114952
# Top 10 variables correlated with latent feature 100 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_L40      0.128069
# 1    ICD10_N90      0.119706
# 2  ATC01_A06AB      0.118644
# 3    ICD01_T18      0.110692
# 4    ICD01_M67      0.109621
# 5    ICD10_M53      0.109007
# 6    ICD01_H91      0.107425
# 7    ICD10_C88      0.107425
# 8    ICD01_C88      0.107425
# 9  ATC10_M04AC      0.106880
# Top 10 variables correlated with latent feature 101 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_D50      0.136805
# 1  ATC01_C10AX      0.127535
# 2    ICD01_B37      0.122853
# 3  ATC01_N01BB      0.121131
# 4    ICD01_N77      0.118944
# 5    ICD01_M11      0.118521
# 6  ATC10_C01CA      0.116436
# 7  ATC10_D05AA      0.113185
# 8    ICD10_Z03      0.112972
# 9    ICD01_E14      0.112374
# Top 10 variables correlated with latent feature 102 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_A09      0.133223
# 1  ATC10_D10AX      0.120010
# 2       crp_m0      0.116513
# 3    ICD01_Z80      0.108638
# 4    ICD10_E55      0.108638
# 5    ICD10_O71      0.108638
# 6    ICD01_H52      0.107997
# 7  ATC10_R06AE      0.105140
# 8    ICD10_O62      0.100055
# 9    ICD01_G25      0.099178
# Top 10 variables correlated with latent feature 103 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_R50      0.137236
# 1  ATC10_R03AC      0.127554
# 2  ATC01_G01AF      0.121723
# 3  ATC01_R03AC      0.118970
# 4    ICD10_R56      0.111617
# 5  ATC10_A02BA      0.108133
# 6    ICD10_H02      0.105102
# 7  ATC10_S01BA      0.104557
# 8    ICD01_S61      0.104303
# 9    ICD10_K01      0.104201
# Top 10 variables correlated with latent feature 104 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_E50      0.135809
# 1    ICD10_E89      0.134894
# 2    ICD10_T92      0.132425
# 3    ICD01_E89      0.123932
# 4  ATC01_R03BA      0.122839
# 5  ATC10_Y93DC      0.121768
# 6    ICD10_F52      0.119475
# 7  ATC01_R03AC      0.116148
# 8  ATC10_R03BA      0.114289
# 9    ICD10_E21      0.113088
# Top 10 variables correlated with latent feature 105 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_Z95      0.137707
# 1    ICD10_S63      0.132938
# 2    ICD10_J00      0.121714
# 3    ICD10_H10      0.119446
# 4    ICD10_N39      0.116894
# 5  ATC01_C03DB      0.113380
# 6  ATC01_J01EE      0.111689
# 7  ATC01_S01ED      0.105089
# 8  ATC01_C01DA      0.101682
# 9    ICD10_I71      0.100593
# Top 10 variables correlated with latent feature 106 for random seed 1
#           Variable  AVG_abs_corr
# 0  edu_lvl_missing      0.188910
# 1      ATC10_L02BA      0.127552
# 2        ICD10_D25      0.118547
# 3        ICD10_M76      0.116116
# 4        ICD10_H15      0.116035
# 5   country_Sweden      0.114802
# 6        ICD10_S80      0.113886
# 7      ATC10_D08AX      0.112755
# 8      ATC10_J01DC      0.110200
# 9        ICD01_R60      0.109572
# Top 10 variables correlated with latent feature 107 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_G03DC      0.133264
# 1  ATC10_M01AH      0.119121
# 2    ICD10_M08      0.115172
# 3  ATC10_N02BA      0.110275
# 4    ICD10_J18      0.102991
# 5    ICD10_R72      0.101516
# 6    ICD01_Z22      0.097474
# 7    ICD10_Z26      0.097405
# 8  ATC01_G02BB      0.097061
# 9  ATC10_S01FA      0.096803
# Top 10 variables correlated with latent feature 108 for random seed 1
#        Variable  AVG_abs_corr
# 0     ICD01_H30      0.126600
# 1     ICD10_I20      0.123463
# 2   ATC10_A10AD      0.118149
# 3     ICD01_K13      0.115202
# 4   ATC10_G02CB      0.115202
# 5     ICD01_L53      0.115202
# 6     ICD01_L04      0.115202
# 7   ATC01_D10BA      0.115202
# 8     ICD10_F53      0.115202
# 9  edu_lvl_>12y      0.113836
# Top 10 variables correlated with latent feature 109 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_L81      0.139677
# 1  ATC01_C08DA      0.139677
# 2    ICD01_R15      0.139677
# 3    ICD01_K42      0.139677
# 4    ICD10_E34      0.139677
# 5  ATC10_J01DC      0.137756
# 6  ATC10_G01AF      0.130923
# 7    ICD10_S24      0.129209
# 8    ICD10_D68      0.127521
# 9  ATC01_J01EE      0.125123
# Top 10 variables correlated with latent feature 110 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC01_J01CR      0.138901
# 1    ICD10_M25      0.123329
# 2  ATC10_N05CM      0.123075
# 3    ICD01_B34      0.116911
# 4    ICD10_S50      0.116911
# 5    ICD10_M76      0.116703
# 6    ICD10_S35      0.111199
# 7    ICD01_I49      0.110531
# 8    ICD10_H33      0.106560
# 9    ICD10_L60      0.106313
# Top 10 variables correlated with latent feature 111 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_C08CA      0.140650
# 1  ATC01_C08CA      0.134824
# 2    ICD01_S43      0.120375
# 3       female      0.112699
# 4  ATC10_M04AA      0.111248
# 5  ATC10_C05BA      0.108210
# 6    ICD10_R14      0.102623
# 7    ICD10_Z22      0.102069
# 8  ATC10_C07AB      0.101726
# 9    ICD01_M07      0.101275
# Top 10 variables correlated with latent feature 112 for random seed 1
#     Variable  AVG_abs_corr
# 0  ICD10_B07      0.131648
# 1  ICD10_D10      0.130702
# 2  ICD01_J34      0.128146
# 3  ICD10_M45      0.128146
# 4  ICD10_H69      0.128146
# 5  ICD10_O61      0.125079
# 6  ICD10_N61      0.119910
# 7  ICD01_E66      0.116917
# 8  ICD01_B07      0.112948
# 9  ICD01_K59      0.111944
# Top 10 variables correlated with latent feature 113 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_O44      0.135924
# 1    ICD10_R51      0.134109
# 2    ICD10_J37      0.128847
# 3    ICD10_A46      0.127916
# 4  ATC10_A01AD      0.124232
# 5    ICD10_N85      0.123768
# 6    ICD01_S42      0.119392
# 7  ATC01_M03BB      0.114646
# 8  ATC10_G03FA      0.113378
# 9    ICD10_O32      0.112880
# Top 10 variables correlated with latent feature 114 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_L01BA      0.118785
# 1  ATC10_R01AA      0.112857
# 2    ICD10_S23      0.112127
# 3    ICD10_E89      0.111775
# 4    ICD10_B91      0.109447
# 5    ICD10_D44      0.109447
# 6    ICD10_A46      0.109071
# 7    ICD10_H35      0.108682
# 8    ICD10_I50      0.108187
# 9    ICD10_K57      0.106862
# Top 10 variables correlated with latent feature 115 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_B18      0.137438
# 1    ICD01_S61      0.129807
# 2  ATC10_R01AD      0.126817
# 3  ATC01_R03AK      0.120969
# 4  ATC10_A01AB      0.113828
# 5    ICD01_R23      0.111780
# 6  ATC10_D10AD      0.111497
# 7  ATC10_R05CB      0.110823
# 8    ICD10_R10      0.108419
# 9  ATC01_A12AX      0.108178
# Top 10 variables correlated with latent feature 116 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_X75QA      0.133468
# 1    ICD01_R69      0.124023
# 2  ATC10_H05AA      0.121970
# 3    ICD10_H53      0.118000
# 4    ICD01_R04      0.113644
# 5  ATC10_J01EA      0.112060
# 6    ICD10_R50      0.111552
# 7    ICD10_N84      0.109356
# 8    ICD10_K05      0.108331
# 9    ICD10_K08      0.108331
# Top 10 variables correlated with latent feature 117 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_M85      0.118509
# 1  ATC10_S01ED      0.116865
# 2    ICD01_K43      0.108172
# 3    ICD01_K58      0.104063
# 4    ICD01_K80      0.096983
# 5    ICD10_M95      0.096449
# 6    ICD01_T93      0.095035
# 7    ICD10_G51      0.095023
# 8  ATC01_P01BB      0.094727
# 9  ATC10_P01AB      0.094611
# Top 10 variables correlated with latent feature 118 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_O85      0.120473
# 1    ICD10_N75      0.120197
# 2  ATC01_J01CF      0.116257
# 3    ICD01_R21      0.113741
# 4  ATC10_D07CA      0.111421
# 5    ICD10_C34      0.111295
# 6    ICD10_N61      0.109335
# 7    ICD10_I73      0.102726
# 8    ICD10_N64      0.102449
# 9    ICD01_N76      0.101756
# Top 10 variables correlated with latent feature 119 for random seed 1
#       Variable  AVG_abs_corr
# 0  ATC10_B01AA      0.138327
# 2  ATC10_A11CB      0.116676
# 1    ICD10_T17      0.116676
# 3  ATC10_C10AB      0.115425
# 4  ATC10_J07AL      0.114676
# 5    ICD10_D12      0.105665
# 6  ATC10_J01MA      0.105147
# 7  ATC10_A11EA      0.104801
# 8  ATC01_N05AN      0.102564
# 9  ATC10_N05AN      0.102564
# Top 10 variables correlated with latent feature 120 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD01_K63      0.122830
# 1    ICD10_H02      0.121668
# 2    ICD01_L91      0.117949
# 3    ICD10_D13      0.117949
# 4  ATC01_A08AB      0.115465
# 5    ICD01_L08      0.113095
# 6    ICD01_F17      0.111500
# 7    ICD10_S80      0.105041
# 8    ICD01_Z82      0.104406
# 9    ICD01_L29      0.103030
# Top 10 variables correlated with latent feature 121 for random seed 1
#       Variable  AVG_abs_corr
# 0    ICD10_J30      0.152135
# 1    ICD01_G47      0.135684
# 2    ICD10_J17      0.135661
# 3    ICD10_G47      0.117940
# 4    ICD01_Z26      0.113680
# 5    ICD10_R10      0.112019
# 6  ATC10_N05BA      0.108881
# 7  ATC10_J01DD      0.108787
# 8    ICD10_L42      0.108787
# 9    ICD10_A56      0.108787
# Top 10 variables correlated with latent feature 122 for random seed 1
#     Variable  AVG_abs_corr
# 0  ICD01_M18      0.132953
# 1  ICD01_S93      0.130452
# 2  ICD10_L53      0.126346
# 3  ICD10_B35      0.116770
# 4  ICD01_M25      0.112223
# 5  ICD01_H26      0.111927
# 6  ICD01_N95      0.110211
# 7  ICD10_N85      0.109117
# 8  ICD01_K25      0.107905
# 9  ICD01_I20      0.107096
# Top 10 variables correlated with latent feature 123 for random seed 1
#       Variable  AVG_abs_corr
# 0      pain_m0      0.137905
# 5    ICD10_G00      0.129774
# 7    ICD01_D69      0.129774
# 6    ICD10_N17      0.129774
# 1    ICD01_D61      0.129774
# 4    ICD10_G94      0.129774
# 2    ICD01_D70      0.129774
# 3    ICD10_B95      0.129774
# 8    ICD10_S01      0.126951
# ...
# ICD10_M19        0.041469
# ATC01_D07AA      0.040800
# ATC10_G03DC      0.040521
# ICD10_Z96        0.040518
# ICD10_D07        0.040490
# hosptime_10      0.040377
# ICD10_Z01        0.040368
# ICD10_K57        0.040288
# Top 10 variables correlated with latent feature 86 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_D02AE      0.046716
# ICD10_E14        0.046265
# ICD10_I80        0.045094
# ICD01_H53        0.043305
# ATC10_C03CA      0.043082
# ATC01_C03CA      0.042771
# hosptime_10      0.042128
# ICD01_O98        0.042102
# ICD01_O75        0.042102
# ATC10_Y93AD      0.042102
# Top 10 variables correlated with latent feature 87 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.049856
# hosptime_01      0.047835
# hospdays_01      0.043682
# das28crp_m0      0.043191
# ATC01_R01AD      0.043114
# ICD10_I80        0.042852
# ATC10_B03BA      0.042778
# ATC01_N05CF      0.042660
# ICD10_N31        0.042517
# tjc28_m0         0.042395
# Top 10 variables correlated with latent feature 88 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_A11EA      0.046206
# ATC10_J01DC      0.045604
# ICD01_Z51        0.045071
# ATC10_A09AA      0.044395
# ATC10_A02AD      0.043935
# ATC01_Y92EA      0.043371
# ICD10_N30        0.043322
# hosptime_10      0.042988
# ATC10_Y92HC      0.042381
# ATC10_Y92HA      0.042381
# Top 10 variables correlated with latent feature 89 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.052184
# ICD01_Z85        0.050786
# hosptime_01      0.046942
# ICD01_R10        0.046611
# hospdays_01      0.046357
# ICD10_I20        0.043906
# ATC10_R03AK      0.043380
# ATC01_D11AX      0.043262
# ATC10_J01AA      0.043149
# ATC10_V07AB      0.042900
# Top 10 variables correlated with latent feature 90 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_N06AB      0.044869
# ICD10_H66        0.042574
# ATC01_G03CX      0.042262
# ICD10_O23        0.042120
# ATC01_A06AD      0.042098
# ICD01_R22        0.041539
# hosptime_10      0.040996
# ATC10_V07AB      0.040810
# ATC10_R03AL      0.040810
# ICD01_G43        0.040810
# Top 10 variables correlated with latent feature 91 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.055277
# ICD10_H51        0.053543
# ICD10_J12        0.053543
# ATC10_R03AL      0.053543
# ATC01_Y93DC      0.053543
# ICD01_R65        0.053543
# ICD10_S76        0.053543
# ATC10_V07AB      0.053543
# ICD01_G43        0.053543
# ICD10_K08        0.050161
# Top 10 variables correlated with latent feature 92 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC10_A06AD      0.043088
# ATC01_C07AA      0.042671
# hosptime_10      0.041820
# haq_m0           0.041362
# ATC10_R05FA      0.040901
# ICD10_N30        0.040839
# ICD10_D68        0.040708
# ICD10_S24        0.040564
# ATC10_C10AX      0.040516
# ICD10_M54        0.040166
# Top 10 variables correlated with latent feature 93 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.044764
# ATC01_A01AA      0.044349
# ICD10_D50        0.043168
# ICD01_T18        0.042628
# ATC01_N05CM      0.042401
# ICD10_N76        0.042106
# ATC01_N02AA      0.042061
# ICD01_Z08        0.041836
# ICD10_O61        0.041470
# ICD10_I83        0.041109
# Top 10 variables correlated with latent feature 94 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.046288
# ICD01_M00        0.045575
# ATC01_C03CA      0.043614
# ICD10_O23        0.043614
# ICD10_R60        0.043286
# ATC10_N05CF      0.043254
# ATC10_S01GA      0.042937
# ATC10_Y90LA      0.042937
# ICD01_Z93        0.042937
# ATC01_Y90KA      0.042937
# Top 10 variables correlated with latent feature 95 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_M79        0.043537
# hosptime_10      0.042935
# ATC01_C07AB      0.042496
# ATC01_B01AC      0.042431
# ICD10_Z03        0.042372
# ICD01_N71        0.042198
# ATC10_B01AC      0.041956
# ICD10_M76        0.041652
# ATC10_G03CA      0.041324
# ATC10_N02AJ      0.041273
# Top 10 variables correlated with latent feature 96 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.046264
# hosptime_01      0.044265
# ICD10_K92        0.043966
# ICD10_G44        0.043586
# ATC10_Y92AD      0.043586
# ICD10_D50        0.043483
# ICD01_R32        0.043344
# ICD10_E11        0.043087
# ATC10_A06AB      0.042183
# ICD10_C20        0.042064
# Top 10 variables correlated with latent feature 97 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.051676
# ICD10_O23        0.047312
# ATC01_D11AX      0.046768
# ATC01_B03BA      0.046737
# ICD01_Z85        0.044618
# ICD10_I80        0.044453
# ATC10_A10BA      0.044446
# ICD10_N91        0.044389
# ICD10_R10        0.044375
# ATC10_Y92BA      0.043995
# Top 10 variables correlated with latent feature 98 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_R15        0.054789
# hosptime_10      0.049127
# ATC01_D10AX      0.046482
# ATC01_G04BX      0.046008
# ATC01_D11AX      0.045163
# ATC01_C03DA      0.044916
# ATC01_A06AD      0.044592
# ICD10_Z50        0.044509
# ICD10_D35        0.044384
# ICD01_K42        0.044144
# Top 10 variables correlated with latent feature 99 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_I10        0.050517
# hosptime_10      0.049806
# haq_m0           0.046021
# ATC10_A06AD      0.045936
# ATC10_C03CA      0.045627
# ATC10_Y92EA      0.045439
# ICD01_E11        0.045409
# ATC01_B03BA      0.044811
# ATC10_Y92BA      0.044630
# ATC10_B03BA      0.044330
# Top 10 variables correlated with latent feature 100 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_C09CA      0.042973
# ICD01_E11        0.042812
# ICD10_I45        0.042776
# ATC10_C09CA      0.042716
# ATC10_J01MA      0.042248
# ICD01_I80        0.042150
# ICD10_R39        0.042087
# ICD10_E11        0.042071
# ICD01_I20        0.041475
# ATC01_C10AA      0.041333
# Top 10 variables correlated with latent feature 101 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.047502
# ICD10_R33        0.043311
# workloss10       0.042551
# ICD01_Z03        0.042448
# ATC10_N05CM      0.042323
# ATC10_A10AE      0.041724
# ATC10_N02AX      0.041583
# ATC10_C03DA      0.041535
# ATC10_A08AB      0.041412
# ATC10_A10BA      0.041333
# Top 10 variables correlated with latent feature 102 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD01_R52        0.045099
# hosptime_10      0.044548
# ATC10_R06AE      0.044281
# ATC01_B01AB      0.043004
# hosptime_01      0.042303
# ATC10_C03CA      0.041487
# ATC10_N05BA      0.041163
# ICD10_Q07        0.040919
# ICD10_R14        0.040444
# ATC01_A07DA      0.040173
# Top 10 variables correlated with latent feature 103 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_O31        0.043272
# ATC01_J01FF      0.042774
# ICD10_E11        0.042042
# ICD10_R52        0.041761
# ICD01_N76        0.041455
# ATC01_A09AA      0.041137
# ATC10_Y92GB      0.041137
# ATC10_Y92BB      0.041137
# ICD10_R63        0.041137
# ATC01_Y90LC      0.041137
# Top 10 variables correlated with latent feature 104 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.057490
# ICD10_R15        0.052741
# ICD01_Z85        0.052442
# ICD10_N39        0.050765
# ICD10_D50        0.049267
# ATC10_C03DA      0.049091
# ICD10_N31        0.049024
# ATC10_B03BA      0.048534
# ICD01_Z92        0.048197
# ATC10_C03CA      0.048078
# Top 10 variables correlated with latent feature 105 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD01_N10        0.042710
# ATC01_J01MA      0.042593
# ATC10_G01AF      0.042229
# ATC10_N05CM      0.041027
# ICD10_O46        0.040976
# ICD01_S66        0.040839
# ICD01_M31        0.040722
# ICD01_M79        0.040495
# ICD10_Z03        0.040052
# ICD10_I73        0.039820
# Top 10 variables correlated with latent feature 106 averaged in 50 random seeds.
#               AVG_abs_corr
# hosptime_10       0.050018
# ATC10_N05AH       0.049273
# ICD10_L29         0.044678
# ATC01_Y92BA       0.043930
# ATC10_A03AX       0.043749
# ICD10_R15         0.043583
# seropositive      0.043554
# ICD10_Z50         0.043509
# ICD01_R65         0.043467
# ICD10_S76         0.043467
# Top 10 variables correlated with latent feature 107 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_A11CC      0.044926
# ATC01_H03AA      0.043191
# ATC10_C03CA      0.042415
# ATC10_D07AC      0.042249
# ATC10_Y93HA      0.041842
# ICD10_O23        0.041229
# ICD10_I50        0.041203
# ATC10_N06AB      0.041151
# ATC10_S01BA      0.041148
# ICD10_M43        0.040855
# Top 10 variables correlated with latent feature 108 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_Z04        0.044343
# hosptime_10      0.044084
# ATC01_A11EA      0.043714
# ICD10_I50        0.042777
# ICD01_R11        0.042639
# ICD10_R15        0.042465
# ATC10_C03DA      0.042068
# ICD10_A49        0.041660
# ICD01_Z92        0.041024
# ICD10_E34        0.040785
# Top 10 variables correlated with latent feature 109 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.048863
# ATC10_C08CA      0.046319
# ATC01_C09DA      0.044628
# ATC10_Y92EA      0.044135
# ATC10_A06AD      0.043830
# ATC10_C09DA      0.043301
# ATC10_Y92BA      0.043277
# ATC10_C03CA      0.042461
# ICD10_N31        0.042420
# ATC10_J01DC      0.042187
# Top 10 variables correlated with latent feature 110 averaged in 50 random seeds.
#               AVG_abs_corr
# hosptime_10       0.046691
# ICD10_O23         0.044462
# ICD10_M80         0.043694
# ATC10_N05CM       0.043616
# ICD10_F31         0.043493
# seronegative      0.043351
# hospdays_10       0.043097
# ICD01_F31         0.042999
# ATC10_N02CC       0.042713
# ATC10_N03AE       0.042563
# Top 10 variables correlated with latent feature 111 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.050441
# ICD01_M70        0.047044
# ATC10_N05CM      0.045381
# ATC01_D06AX      0.043902
# ATC10_A10AD      0.043856
# ICD10_I50        0.043534
# ATC10_C09CA      0.043053
# ICD01_G40        0.042986
# ICD01_G43        0.042968
# ATC01_Y93DC      0.042968
# Top 10 variables correlated with latent feature 112 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.059871
# ICD01_Z85        0.051877
# ICD10_R41        0.049287
# hosptime_01      0.048290
# ICD01_F33        0.048059
# ICD10_R15        0.047929
# ATC10_A10AD      0.047661
# ATC01_N05AH      0.047020
# ATC10_A06AD      0.046617
# ICD01_R65        0.046218
# Top 10 variables correlated with latent feature 113 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_O23        0.044811
# ICD10_O47        0.044210
# ICD10_O99        0.042963
# ATC10_J01CA      0.042592
# ICD10_C19        0.042233
# ICD10_Z91        0.042080
# ATC10_N05CM      0.041358
# ATC01_A07AA      0.041354
# ATC01_N03AX      0.040897
# ICD10_O26        0.040706
# Top 10 variables correlated with latent feature 114 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_N01BB      0.043886
# hosptime_01      0.043842
# ATC01_C10AX      0.043621
# ICD01_C44        0.043371
# ATC10_A02AD      0.043263
# ICD10_H26        0.042414
# hosptime_10      0.042316
# ATC01_R01AD      0.042241
# ICD10_R10        0.042112
# ATC10_R01AA      0.041972
# Top 10 variables correlated with latent feature 115 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_R15        0.046944
# hosptime_10      0.046450
# ICD10_R60        0.045371
# ICD10_N31        0.044785
# ICD01_Z36        0.044405
# ICD01_O47        0.044405
# ICD01_O71        0.044405
# ICD01_S62        0.044405
# ICD01_O99        0.044405
# ATC01_N05BE      0.044405
# Top 10 variables correlated with latent feature 116 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.059233
# ATC10_Y90BA      0.054861
# ATC10_Y90LA      0.054861
# ICD10_C21        0.054861
# ATC10_Y90CA      0.054861
# ATC10_S01GA      0.054861
# ICD01_K91        0.054861
# ATC10_Y90MB      0.054861
# ATC01_Y90CA      0.054861
# ATC10_Y90KA      0.054861
# Top 10 variables correlated with latent feature 117 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC10_N05CF      0.045619
# ATC10_G03AB      0.042858
# ATC10_N05AH      0.041901
# ATC01_N05AH      0.041579
# ICD10_I65        0.040364
# ICD01_M08        0.040246
# ICD10_M79        0.040190
# ICD01_M81        0.040012
# ATC10_D01AE      0.039986
# hosptime_10      0.039574
# Top 10 variables correlated with latent feature 118 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_S01ED      0.042234
# hosptime_01      0.041822
# ICD10_Z50        0.041735
# ATC01_A10BH      0.041599
# ATC10_N05AA      0.041393
# ATC01_C09CA      0.041050
# ICD10_Z88        0.041049
# ICD10_E11        0.040879
# ICD10_M19        0.040803
# ATC01_J01MA      0.040750
# Top 10 variables correlated with latent feature 119 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.047878
# ICD10_E50        0.043336
# ATC10_J07BA      0.042926
# ATC01_D06AX      0.042889
# ATC01_A06AD      0.042776
# ICD10_R56        0.042124
# ATC01_N05CF      0.042118
# ATC10_Y92AD      0.042088
# ICD01_E11        0.041695
# ICD01_H61        0.041420
# Top 10 variables correlated with latent feature 120 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC10_A06AC      0.044007
# ICD10_I70        0.042431
# ATC01_A03AX      0.042228
# ATC10_A08AX      0.042019
# ICD10_Z72        0.042006
# ATC10_D07XA      0.041795
# ICD01_Z51        0.041609
# ICD01_M25        0.041380
# ICD01_E11        0.041270
# ICD10_R60        0.041209
# Top 10 variables correlated with latent feature 121 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC10_C03CA      0.048306
# hosptime_10      0.046799
# ICD10_R15        0.045000
# ATC10_N02AA      0.044699
# ATC01_C03CA      0.043759
# ICD01_K44        0.043667
# ATC10_A02AD      0.042894
# ATC01_C01DA      0.042839
# ATC01_A11EA      0.042249
# ICD01_T18        0.042014
# Top 10 variables correlated with latent feature 122 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.048603
# ATC10_B03BA      0.045062
# ICD10_H92        0.043869
# ATC01_B03BA      0.043831
# ATC10_A02BD      0.043483
# ICD01_E11        0.042580
# ICD10_M05        0.042162
# ATC01_C03DA      0.041836
# ICD10_N30        0.041774
# ATC10_G04BD      0.041515
# Top 10 variables correlated with latent feature 123 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.050045
# ICD10_M79        0.046410
# ICD10_R19        0.044302
# ICD01_Z85        0.043057
# ATC10_N05CF      0.042703
# ATC01_N05CF      0.042179
# ICD01_M71        0.041869
# ATC10_C03CA      0.041578
# ATC01_D11AX      0.041405
# ATC10_S01XA      0.041236
# Top 10 variables correlated with latent feature 124 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.047929
# ICD10_N88        0.047413
# ATC01_A10BH      0.044686
# ICD01_J22        0.044196
# ATC10_Y93DB      0.044196
# ATC10_J01XC      0.044196
# ICD10_R51        0.044172
# ICD10_D50        0.043741
# ATC10_G02CX      0.043483
# ICD10_S09        0.043483
# Top 10 variables correlated with latent feature 125 averaged in 50 random seeds.
#              AVG_abs_corr
# ATC01_Y93DC      0.049901
# ICD01_R65        0.049901
# ATC10_R03AL      0.049901
# ICD10_S76        0.049901
# ICD10_J12        0.049901
# ICD01_G43        0.049901
# ICD10_H51        0.049901
# ATC10_V07AB      0.049901
# ICD01_Z85        0.049348
# ICD10_R41        0.047676
# Top 10 variables correlated with latent feature 126 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD10_R15        0.050970
# ATC01_C03DA      0.049750
# hosptime_10      0.048493
# ICD10_N31        0.044780
# haq_m0           0.043927
# ATC10_R01AA      0.043923
# ATC01_J01MA      0.043878
# ATC10_J01DC      0.043520
# ICD10_Z35        0.043509
# ATC10_C03DA      0.043232
# Top 10 variables correlated with latent feature 127 averaged in 50 random seeds.
#              AVG_abs_corr
# ICD01_Z85        0.043623
# ICD10_F52        0.043416
# ICD10_S06        0.042903
# ICD01_R10        0.042562
# ICD10_I20        0.042471
# ICD10_I10        0.042409
# ICD01_N71        0.042393
# ATC01_N02AA      0.042296
# ATC10_C03CA      0.042278
# ATC01_N03AF      0.041922
# Top 10 variables correlated with latent feature 128 averaged in 50 random seeds.
#              AVG_abs_corr
# hosptime_10      0.043503
# ICD10_R10        0.043399
# ATC01_P01BA      0.043397
# ICD01_M05        0.042665
# ATC01_S01XA      0.042550
# ATC01_S01BC      0.042462
# ATC10_B03BA      0.042237
# ICD01_Z96        0.041772
# ATC01_S01ED      0.041270
# ICD10_J30        0.040936
